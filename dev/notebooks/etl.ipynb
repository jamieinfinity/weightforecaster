# %% [markdown]
# ## Setup

# %%
import sys
toolpath = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/weightforecaster/server/src'
sys.path.append(toolpath)

# %load_ext autoreload
# %autoreload 2

from wtfc_utils import etl_utils as etl

import datetime
# import time
import configparser
import json
import requests
from sqlalchemy import create_engine

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import fitbit
import myfitnesspal
from nokia import NokiaAuth, NokiaApi, NokiaCredentials # Withings

# %%
server_dir = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/weightforecaster/server/'
cfg_file = server_dir + 'config/api_params.cfg'
db_dir = server_dir + 'db/'
backups_dir = db_dir + 'backups/'
db_name = 'weightforecaster'
db_ext = '.db'
db_file_name = db_dir + db_name + db_ext

# %%
db_file_name
# Out:
# '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/weightforecaster/server/db/weightforecaster.db'

# %% [markdown]
# ## Load DB

# %%
# See: https://pandas.pydata.org/pandas-docs/stable/io.html#advanced-sqlalchemy-queries
engine = create_engine('sqlite:///'+db_file_name)

# %%
with engine.connect() as conn, conn.begin():
    db_df = pd.read_sql_table('fitness', conn, index_col='date', parse_dates=['date'])

# %%
db_df.tail(5)
# Out:
#             weight    steps  calories  weight_imputed
# date
# 2020-03-27   168.6  10881.0    2243.0               0
# 2020-03-28   168.2   5905.0    1987.0               0
# 2020-03-29   166.7  13504.0    1961.0               0
# 2020-03-30   165.4  12350.0    1859.0               0
# 2020-03-31   165.7  15183.0    2162.0               0

# %% [markdown]
# ## Initialize API configs

# %% [markdown]
# ### Nokia / Withings

# %% [markdown]
# See the following:
# - https://github.com/orcasgit/python-nokia
# - https://github.com/orcasgit/python-nokia/blob/master/nokia/__init__.py

# %%
parser = configparser.ConfigParser()
parser.read(cfg_file)
CLIENT_ID = parser.get('withings', 'client_id')
CLIENT_SECRET = parser.get('withings', 'client_secret')
REDIRECT_URI = parser.get('withings', 'redirect_uri')

auth = NokiaAuth(CLIENT_ID, CLIENT_SECRET, callback_uri=REDIRECT_URI)
authorize_url = auth.get_authorize_url()

# open the following in a browser, click allow, it redirects. Copy the 'code' parameter from that url.
print(authorize_url)
# Out:
# https://account.withings.com/oauth2_user/authorize2?response_type=code&client_id=4ce14f6c8de5fc71bed6983fa0cf85b5c43722421a9f435cf8b2b77d46c755c9&redirect_uri=https%3A%2F%2Fjamieinfinity.github.io%2Fcodegraphy%2Fblog%2F&scope=user.metrics&state=LRrDZMU526Hxcn1GLjAGMvmo6IvY4x

# %%
# set this to the alphanumeric string value appearing for the 'code' parameter in the url
code = 'xxx'

# %%
res = requests.post(url = 'https://account.withings.com/oauth2/token', 
              data = {
                  'grant_type':'authorization_code',
                  'client_id':CLIENT_ID,
                  'client_secret':CLIENT_SECRET,
                  'redirect_uri':REDIRECT_URI,
                  'code':code
              })   
token_dict = json.loads(res.content)
token_dict
# Out:
# b'{"access_token":"cbf5cb2220a3c212f009ada3aaa5a3f77a77d8fc","expires_in":10800,"token_type":"Bearer","scope":"user.metrics","refresh_token":"f8959d2feb5cbb4ca75011860408b618d0a20f68","userid":"2178209"}'

# %%
etl.persist_nokia_refresh_token(token_dict, cfg_file)

# %% [markdown]
# ### Fitbit

# %% [markdown]
# See the following:
#
# - https://python-fitbit.readthedocs.io/en/latest/

# %% [markdown]
# In a terminal, cd to location of python-fitbit repo (clone it from github: https://github.com/orcasgit/python-fitbit).
#
# Then run the following:
#
# ```
# python gather_keys_oauth2.py <client_key> <client_secret>
# ```
#
# This script has a callback function for persisting the refresh token. Make sure the path to the api_params.cfg file is properly set (probably good to test it out…)

# %% [markdown]
# ### MyFitnessPal

# %% [markdown]
# See the following:
#
# - https://github.com/coddingtonbear/python-myfitnesspal

# %% [markdown]
# In a terminal, run the following command to set up authentication (locally storing your user credentials):
#
# ```
# myfitnesspal store-password my_username
# ```

# %% [markdown]
# ## Test etl scripting

# %%
db_df_updated = db_df.copy()

# %%
etl.get_target_date_endpoints('steps', db_df_updated)
# Out:
# [datetime.datetime(2020, 3, 17, 0, 0), datetime.datetime(2020, 4, 21, 0, 0)]

# %% [markdown]
# ### Fitbit

# %%
db_df_updated = etl.refresh_steps(cfg_file, engine, db_df_updated)
# Out:
# REFRESHING STEPS...

# %%
db_df_updated.tail(28)
# Out:
#             weight    steps  calories  weight_imputed
# date
# 2020-03-25   166.4  14243.0    1995.0             0.0
# 2020-03-26   167.1  11308.0    1937.0             0.0
# 2020-03-27   168.6  10881.0    2243.0             0.0
# 2020-03-28   168.2   5905.0    1987.0             0.0
# 2020-03-29   166.7  13504.0    1961.0             0.0
# 2020-03-30   165.4  12350.0    1859.0             0.0
# 2020-03-31   165.7  15183.0    2162.0             0.0
# 2020-04-01     NaN   9067.0       NaN             NaN
# 2020-04-02     NaN  14037.0       NaN             NaN
# 2020-04-03     NaN   2823.0       NaN             NaN
# 2020-04-04     NaN   2422.0       NaN             NaN
# 2020-04-05     NaN   3710.0       NaN             NaN
# 2020-04-06     NaN  11771.0       NaN             NaN
# 2020-04-07     NaN  10205.0       NaN             NaN
# 2020-04-08     NaN  10857.0       NaN             NaN
# 2020-04-09     NaN  11040.0       NaN             NaN
# 2020-04-10     NaN  13035.0       NaN             NaN
# 2020-04-11     NaN   5642.0       NaN             NaN
# 2020-04-12     NaN   6359.0       NaN             NaN
# 2020-04-13     NaN  10841.0       NaN             NaN
# 2020-04-14     NaN  10962.0       NaN             NaN
# 2020-04-15     NaN  13027.0       NaN             NaN
# 2020-04-16     NaN  12252.0       NaN             NaN
# 2020-04-17     NaN   2786.0       NaN             NaN
# 2020-04-18     NaN  12423.0       NaN             NaN
# 2020-04-19     NaN  13062.0       NaN             NaN
# 2020-04-20     NaN   4706.0       NaN             NaN
# 2020-04-21     NaN  12247.0       NaN             NaN

# %% [markdown]
# ### MyFitnessPal

# %%
db_df_updated = etl.refresh_calories(engine, db_df_updated)
# Out:
# REFRESHING CALORIES...

# %%
db_df_updated.tail(28)
# Out:
#             weight    steps  calories  weight_imputed
# date
# 2020-03-25   166.4  14243.0    1995.0             0.0
# 2020-03-26   167.1  11308.0    1937.0             0.0
# 2020-03-27   168.6  10881.0    2243.0             0.0
# 2020-03-28   168.2   5905.0    1987.0             0.0
# 2020-03-29   166.7  13504.0    1961.0             0.0
# 2020-03-30   165.4  12350.0    1859.0             0.0
# 2020-03-31   165.7  15183.0    2162.0             0.0
# 2020-04-01     NaN   9067.0    2101.0             NaN
# 2020-04-02     NaN  14037.0    1641.0             NaN
# 2020-04-03     NaN   2823.0    2292.0             NaN
# 2020-04-04     NaN   2422.0    2139.0             NaN
# 2020-04-05     NaN   3710.0    2254.0             NaN
# 2020-04-06     NaN  11771.0    2050.0             NaN
# 2020-04-07     NaN  10205.0    1876.0             NaN
# 2020-04-08     NaN  10857.0    2067.0             NaN
# 2020-04-09     NaN  11040.0    2073.0             NaN
# 2020-04-10     NaN  13035.0    2191.0             NaN
# 2020-04-11     NaN   5642.0    2331.0             NaN
# 2020-04-12     NaN   6359.0    2026.0             NaN
# 2020-04-13     NaN  10841.0    1977.0             NaN
# 2020-04-14     NaN  10962.0    2432.0             NaN
# 2020-04-15     NaN  13027.0    2306.0             NaN
# 2020-04-16     NaN  12252.0    2193.0             NaN
# 2020-04-17     NaN   2786.0    2426.0             NaN
# 2020-04-18     NaN  12423.0    2605.0             NaN
# 2020-04-19     NaN  13062.0    2558.0             NaN
# 2020-04-20     NaN   4706.0    2166.0             NaN
# 2020-04-21     NaN  12247.0    1191.0             NaN

# %% [markdown]
# ### Nokia / Withings

# %%
db_df_updated = etl.refresh_weight(cfg_file, engine, db_df_updated)

# %%
db_df_updated[db_df_updated.index > '2019-10-30']
# Out:
#                 weight    steps  calories  weight_imputed
# date
# 2019-10-31  179.200000  14476.0     580.0             NaN
# 2019-11-01  178.409167  24122.0    1843.0             1.0
# 2019-11-02  177.873564  22211.0    2252.0             1.0
# 2019-11-03  177.450878  20224.0    2334.0             1.0
# 2019-11-04  177.157086  13557.0    1786.0             1.0
# ...                ...      ...       ...             ...
# 2020-04-17  169.000000   2786.0    2426.0             NaN
# 2020-04-18  170.300000  12423.0    2605.0             NaN
# 2020-04-19  170.000000  13062.0    2558.0             NaN
# 2020-04-20  169.900000   4706.0    2166.0             NaN
# 2020-04-21  168.300000  12247.0    1191.0             NaN
#
# [174 rows x 4 columns]

# %% [markdown]
# ## Impute weight

# %%
db_df_updated = etl.impute_missing_weights(engine, db_df_updated)
# Out:
# IMPUTING MISSING WEIGHTS...

# %%
db_df_updated[db_df_updated.index > '2019-10-30']
# Out:
#                 weight    steps  calories  weight_imputed
# date
# 2019-10-31  179.200000  14476.0     580.0             0.0
# 2019-11-01  178.212098  24122.0    1843.0             1.0
# 2019-11-02  177.594992  22211.0    2252.0             1.0
# 2019-11-03  177.100407  20224.0    2334.0             1.0
# 2019-11-04  176.751546  13557.0    1786.0             1.0
# ...                ...      ...       ...             ...
# 2020-04-17  169.000000   2786.0    2426.0             0.0
# 2020-04-18  170.300000  12423.0    2605.0             0.0
# 2020-04-19  170.000000  13062.0    2558.0             0.0
# 2020-04-20  169.900000   4706.0    2166.0             0.0
# 2020-04-21  168.300000  12247.0    1191.0             0.0
#
# [174 rows x 4 columns]

# %% [markdown]
# ## Add rolling week-averaged columns

# %%
db_df_updated = etl.add_roll_avg_columns(engine, db_df_updated)
# Out:
# ADDING ROLLING AVG COLUMNS...

# %%
db_df_updated.tail(21)
# Out:
#             weight    steps  calories  weight_imputed  w_7day_avg  \
# date
# 2020-04-01   168.3   9067.0    2101.0             0.0  167.142857
# 2020-04-02   167.1  14037.0    1641.0             0.0  167.142857
# 2020-04-03   169.1   2823.0    2292.0             0.0  167.214286
# 2020-04-04   167.1   2422.0    2139.0             0.0  167.057143
# 2020-04-05   166.9   3710.0    2254.0             0.0  167.085714
# 2020-04-06   167.0  11771.0    2050.0             0.0  167.314286
# 2020-04-07   168.4  10205.0    1876.0             0.0  167.700000
# 2020-04-08   168.2  10857.0    2067.0             0.0  167.685714
# 2020-04-09   169.6  11040.0    2073.0             0.0  168.042857
# 2020-04-10   169.1  13035.0    2191.0             0.0  168.042857
# 2020-04-11   168.8   5642.0    2331.0             0.0  168.285714
# 2020-04-12   168.4   6359.0    2026.0             0.0  168.500000
# 2020-04-13   166.6  10841.0    1977.0             0.0  168.442857
# 2020-04-14   167.6  10962.0    2432.0             0.0  168.328571
# 2020-04-15   168.3  13027.0    2306.0             0.0  168.342857
# 2020-04-16   168.1  12252.0    2193.0             0.0  168.128571
# 2020-04-17   169.0   2786.0    2426.0             0.0  168.114286
# 2020-04-18   170.3  12423.0    2605.0             0.0  168.328571
# 2020-04-19   170.0  13062.0    2558.0             0.0  168.557143
# 2020-04-20   169.9   4706.0    2166.0             0.0  169.028571
# 2020-04-21   168.3  12247.0    1191.0             0.0  169.128571
#
#              c_7day_avg    s_7day_avg  w_7day_avg_last_week  \
# date
# 2020-04-01  2035.714286  11171.142857            168.142857
# 2020-04-02  1993.428571  11561.000000            167.942857
# 2020-04-03  2000.428571  10409.857143            168.257143
# 2020-04-04  2022.142857   9912.285714            168.142857
# 2020-04-05  2064.000000   8513.142857            167.628571
# 2020-04-06  2091.285714   8430.428571            167.242857
# 2020-04-07  2050.428571   7719.285714            166.871429
# 2020-04-08  2045.571429   7975.000000            167.142857
# 2020-04-09  2107.285714   7546.857143            167.142857
# 2020-04-10  2092.857143   9005.714286            167.214286
# 2020-04-11  2120.285714   9465.714286            167.057143
# 2020-04-12  2087.714286   9844.142857            167.085714
# 2020-04-13  2077.285714   9711.285714            167.314286
# 2020-04-14  2156.714286   9819.428571            167.700000
# 2020-04-15  2190.857143  10129.428571            167.685714
# 2020-04-16  2208.000000  10302.571429            168.042857
# 2020-04-17  2241.571429   8838.428571            168.042857
# 2020-04-18  2280.714286   9807.142857            168.285714
# 2020-04-19  2356.714286  10764.714286            168.500000
# 2020-04-20  2383.714286   9888.285714            168.442857
# 2020-04-21  2206.428571  10071.857143            168.328571
#
#             c_7day_avg_last_week  s_7day_avg_last_week  w_7day_avg_weekly_diff
# date
# 2020-04-01           2245.857143          12222.142857               -1.000000
# 2020-04-02           2232.714286          12637.857143               -0.800000
# 2020-04-03           2204.000000          11687.428571               -1.042857
# 2020-04-04           2213.142857          10004.142857               -1.085714
# 2020-04-05           2111.857143          10610.714286               -0.542857
# 2020-04-06           1987.714286          10263.285714                0.071429
# 2020-04-07           2020.571429          11910.571429                0.828571
# 2020-04-08           2035.714286          11171.142857                0.542857
# 2020-04-09           1993.428571          11561.000000                0.900000
# 2020-04-10           2000.428571          10409.857143                0.828571
# 2020-04-11           2022.142857           9912.285714                1.228571
# 2020-04-12           2064.000000           8513.142857                1.414286
# 2020-04-13           2091.285714           8430.428571                1.128571
# 2020-04-14           2050.428571           7719.285714                0.628571
# 2020-04-15           2045.571429           7975.000000                0.657143
# 2020-04-16           2107.285714           7546.857143                0.085714
# 2020-04-17           2092.857143           9005.714286                0.071429
# 2020-04-18           2120.285714           9465.714286                0.042857
# 2020-04-19           2087.714286           9844.142857                0.057143
# 2020-04-20           2077.285714           9711.285714                0.585714
# 2020-04-21           2156.714286           9819.428571                0.800000
