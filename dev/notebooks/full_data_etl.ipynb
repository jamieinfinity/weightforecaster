# %% [markdown]
# # Full Data ETL

# %% [markdown]
# ## Setup

# %%
import shutil
import datetime
import time
import numpy as np
import pandas as pd
import configparser
import fitbit
import myfitnesspal # was using '1.13.4' before upgraded to '1.16.1'
from nokia import NokiaApi, NokiaCredentials  # Withings
from sqlalchemy import create_engine
import json

pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Files

# %%
# weight forecaster db
server_dir = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/weightforecaster/server/'
db_dir = server_dir + 'db/'
backups_dir = db_dir + 'backups/'
db_name = 'weightforecaster'
db_ext = '.db'
db_file_name = db_dir + db_name + db_ext
db_seed_name = db_dir + 'SEED_weightforecaster_2013-01-01_to_2016-12-25' + db_ext

# config file
cfg_file = server_dir + 'config/api_params.cfg'


# weight
logger_file = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/weight/pre_withings/loggr_weight.csv'
askmeevery_file = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/weight/pre_withings/askmeevery_weight.csv'
withings_file = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/weight/withings/data_JAM_1611609119/weight.csv'
weight_full_file = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/weight/weight_full.csv'

# food
food_tot_file = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/food/food_tot.csv'
food_meals_tot_file = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/food/food_meals_tot.csv'
food_diary_json_file = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/food/food_diary.json'
food_diary_file = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/food/food_diary.csv'

# fitbit
steps_daily_file = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/fitbit/steps_daily.csv'
steps_activity_dir = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/fitbit/activities/'
steps_detail_dir = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/fitbit/detailed_steps/'
hr_detail_dir = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/fitbit/detailed_heart_rate/'
sleep_detail_dir = '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/fitbit/detailed_sleep/'

# %% [markdown]
# ### Functions

# %%
def persist_fitbit_refresh_token(token_dict, cfg_file):
    parser = configparser.ConfigParser()
    parser.read(cfg_file)
    parser.set('fitbit', 'access_token', token_dict['access_token'])
    parser.set('fitbit', 'refresh_token', token_dict['refresh_token'])
    parser.set('fitbit', 'expires_at', "{:.6f}".format(token_dict['expires_at']))
    with open(cfg_file, 'w') as configfile:
        parser.write(configfile)


def ts():
    return int((
        datetime.datetime.utcnow() - datetime.datetime(1970, 1, 1)
    ).total_seconds())


def persist_nokia_refresh_token(token_dict, cfg_file):
    exp_time = str(ts()+int(token_dict['expires_in']))
    parser = configparser.ConfigParser()
    parser.read(cfg_file)
    parser.set('nokia', 'access_token', token_dict['access_token'])
    parser.set('nokia', 'refresh_token', token_dict['refresh_token'])
    parser.set('nokia', 'token_type', token_dict['token_type'])
    parser.set('nokia', 'token_expiry', exp_time)
    if 'user_id' in token_dict:
        parser.set('nokia', 'user_id', token_dict['userid'])
    with open(cfg_file, 'w') as configfile:
        parser.write(configfile)

# %% [markdown]
# ### Load DB

# %%
engine = create_engine('sqlite:///'+db_file_name)
with engine.connect() as conn, conn.begin():
    db_df = pd.read_sql_table('fitness', conn, index_col='date', parse_dates=['date'])
    
engine = create_engine('sqlite:///'+db_seed_name)
with engine.connect() as conn, conn.begin():
    db_seed_df = pd.read_sql_table('fitness', conn, index_col='date', parse_dates=['date'])

# %%
db_df.tail(10)
# Out:
#             weight  calories    steps  weight_imputed  w_7day_avg  \
# date
# 2021-01-25   152.4    2265.0  11149.0             NaN  152.814286
# 2021-01-26   153.8    2143.0  11689.0             NaN  152.985714
# 2021-01-27   153.8    2297.0  11362.0             NaN  153.157143
# 2021-01-28   153.4    3401.0  13443.0             NaN  153.228571
# 2021-01-29   153.7    1160.0  10981.0             NaN  153.342857
# 2021-01-30   154.2       NaN   2760.0             NaN         NaN
# 2021-01-31   155.5       NaN   8849.0             NaN         NaN
# 2021-02-01   157.3       NaN  11742.0             NaN         NaN
# 2021-02-02   155.3       NaN  13013.0             NaN         NaN
# 2021-02-03   155.2       NaN   9018.0             NaN         NaN
#
#              c_7day_avg    s_7day_avg  w_7day_avg_last_week  \
# date
# 2021-01-25  2053.571429  15047.285714            155.257143
# 2021-01-26  2121.714286  13668.285714            154.800000
# 2021-01-27  2165.714286  12886.857143            154.400000
# 2021-01-28  2338.428571  12399.285714            153.857143
# 2021-01-29  2217.714286  11833.142857            153.257143
# 2021-01-30          NaN           NaN                   NaN
# 2021-01-31          NaN           NaN                   NaN
# 2021-02-01          NaN           NaN                   NaN
# 2021-02-02          NaN           NaN                   NaN
# 2021-02-03          NaN           NaN                   NaN
#
#             c_7day_avg_last_week  s_7day_avg_last_week  w_7day_avg_weekly_diff
# date
# 2021-01-25           2167.714286          14029.714286               -2.442857
# 2021-01-26           2065.714286          14642.142857               -1.814286
# 2021-01-27           2002.000000          15322.428571               -1.242857
# 2021-01-28           1913.000000          16166.714286               -0.628571
# 2021-01-29           1878.285714          16550.571429                0.085714
# 2021-01-30                   NaN                   NaN                     NaN
# 2021-01-31                   NaN                   NaN                     NaN
# 2021-02-01                   NaN                   NaN                     NaN
# 2021-02-02                   NaN                   NaN                     NaN
# 2021-02-03                   NaN                   NaN                     NaN

# %% [markdown]
# ## Initialize API configs (one-time eval)

# %% [markdown]
# ### Nokia / Withings

# %% [markdown]
# See the following:
# - https://github.com/orcasgit/python-nokia
# - https://github.com/orcasgit/python-nokia/blob/master/nokia/__init__.py

# %%
parser = configparser.ConfigParser()
parser.read(cfg_file)
CLIENT_ID = parser.get('withings', 'client_id')
CLIENT_SECRET = parser.get('withings', 'client_secret')
REDIRECT_URI = parser.get('withings', 'redirect_uri')

auth = NokiaAuth(CLIENT_ID, CLIENT_SECRET, callback_uri=REDIRECT_URI)
authorize_url = auth.get_authorize_url()

# open the following in a browser, click allow, it redirects. Copy the 'code' parameter from that url.
print(authorize_url)

# %%
# set this to the alphanumeric string value appearing for the 'code' parameter in the url
code = 'xxx'

# %%
res = requests.post(url = 'https://account.withings.com/oauth2/token', 
              data = {
                  'grant_type':'authorization_code',
                  'client_id':CLIENT_ID,
                  'client_secret':CLIENT_SECRET,
                  'redirect_uri':REDIRECT_URI,
                  'code':code
              })   
token_dict = json.loads(res.content)
token_dict

# %%
etl.persist_nokia_refresh_token(token_dict, cfg_file)

# %% [markdown]
# ### Fitbit

# %% [markdown]
# See the following:
#
# - https://python-fitbit.readthedocs.io/en/latest/

# %% [markdown]
# In a terminal, cd to location of python-fitbit repo (clone it from github: https://github.com/orcasgit/python-fitbit).
#
# Then run the following:
#
# ```
# python gather_keys_oauth2.py <client_key> <client_secret>
# ```
#
# This script has a callback function for persisting the refresh token. Make sure the path to the api_params.cfg file is properly set (probably good to test it out…)

# %% [markdown]
# ### MyFitnessPal

# %% [markdown]
# See the following:
#
# - https://github.com/coddingtonbear/python-myfitnesspal

# %% [markdown]
# In a terminal, run the following command to set up authentication (locally storing your user credentials):
#
# ```
# myfitnesspal store-password my_username
# ```

# %% [markdown]
# ## Weight

# %% [markdown]
# ### Pre-Withings data

# %%
ame = pd.read_csv(askmeevery_file).rename({'original':'wgt_ame'}, axis=1).drop({'answer', 'unit'}, axis=1)
ame.date = pd.to_datetime([x.date() for x in pd.to_datetime(ame.date)])
ame = ame.sort_values('date').copy().reset_index(drop=True)

logger=pd.read_csv(logger_file).rename({'weight':'wgt_logger'}, axis=1)
logger.date = pd.to_datetime([x.date() for x in pd.to_datetime(logger.date)])
logger = logger.sort_values('date').copy().reset_index(drop=True)

# %% [markdown]
# ### Withings data

# %%
withings=pd.read_csv(withings_file).rename({'Weight (lb)': 'wgt_withings'}, axis=1)
withings['date'] = pd.to_datetime([x.date() for x in pd.to_datetime(withings.Date)])
withings['timestamp'] = pd.to_datetime(withings.Date)
withings.drop(['Date', 'Comments'], axis=1, inplace=True)
withings = withings.sort_values('timestamp')[['date', 'wgt_withings', 'timestamp', 'Fat mass (lb)', 'Bone mass (lb)', 'Muscle mass (lb)', 'Hydration (lb)']].copy().reset_index(drop=True)

# eliminate multiple measurements in a day by taking last measured value on that day
withings = withings.groupby('date').last().reset_index()

# %%
withings.dtypes
# Out:
# date                datetime64[ns]
# wgt_withings               float64
# timestamp           datetime64[ns]
# Fat mass (lb)              float64
# Bone mass (lb)             float64
# Muscle mass (lb)           float64
# Hydration (lb)             float64
# dtype: object

# %%
withings.tail()
# Out:
#            date  wgt_withings           timestamp  Fat mass (lb)  \
# 1971 2021-01-21         152.9 2021-01-21 07:07:59           23.1
# 1972 2021-01-22         153.0 2021-01-22 07:10:54           23.5
# 1973 2021-01-23         153.6 2021-01-23 07:29:43           23.8
# 1974 2021-01-24         152.7 2021-01-24 07:44:02           22.9
# 1975 2021-01-25         152.4 2021-01-25 07:28:44           23.5
#
#       Bone mass (lb)  Muscle mass (lb)  Hydration (lb)
# 1971             6.5             123.3            88.7
# 1972             6.5             123.0            88.3
# 1973             6.5             123.3            88.6
# 1974             6.5             123.3            88.8
# 1975             6.5             122.5            87.8

# %% [markdown]
# #### API

# %% [markdown]
# **NOTE**
#
# It was easier for the purposes of an infrequent data dump, to just download the data from the Withings web site (which is self explanatory). But I include the code here for the API if needed.
#
# In the code below, meastype=1 refers only to weight. I couldn't find a way to grab all measure types in one call. The list of meastype codes are on the API ref page on the web.

# %%
# parser = configparser.ConfigParser()
# parser.read(cfg_file)

# client_id = parser.get('nokia', 'client_id')
# client_secret = parser.get('nokia', 'client_secret')
# access_token = parser.get('nokia', 'access_token')
# token_expiry = parser.get('nokia', 'token_expiry')
# token_type = parser.get('nokia', 'token_type')
# refresh_token = parser.get('nokia', 'refresh_token')
# user_id = parser.get('nokia', 'user_id')

# creds = NokiaCredentials(access_token=access_token,
#                          token_expiry=token_expiry,
#                          token_type=token_type,
#                          refresh_token=refresh_token,
#                          user_id=user_id,
#                          client_id=client_id,
#                          consumer_secret=client_secret)

# client = NokiaApi(creds, refresh_cb=(lambda x: persist_nokia_refresh_token(x, cfg_file)))

# %%
# measures = client.get_measures(meastype=1)
# len(measures)

# %%
# weight_json = [{'weight':(float("{:.1f}".format(x.weight*2.20462))), 'date':x.date.strftime('%Y-%m-%d')} for x in measures]

# %% [markdown]
# ### Merging datasets

# %%
weight_full = pd.merge(ame, logger, how='outer', on='date')
weight_full = pd.merge(weight_full, withings, how='outer', on='date')
weight_full = weight_full.sort_values('date').copy().reset_index(drop=True)

# %%
dates_df = pd.DataFrame({'date':pd.date_range('2013-01-01', '2021-01-24', freq='d')})
print(len(dates_df))

weight_full = pd.merge(dates_df, weight_full, on='date', how='left')
print(len(weight_full))
# Out:
# 2946
# 2946

# %%
def assign_wgt(x):
    wgt = np.nan
    if x['wgt_withings'] > 0:
        wgt = x['wgt_withings']
    elif x['wgt_logger'] > 0:
        wgt = x['wgt_logger']
    elif x['wgt_ame'] > 0:
        wgt = x['wgt_ame']
    return wgt

weight_full['weight'] = weight_full.apply(assign_wgt, axis=1)
weight_full = weight_full[[
    'date',
    'weight',
    'wgt_ame',
    'wgt_logger',
    'wgt_withings',
    'timestamp',
    'Fat mass (lb)',
    'Bone mass (lb)',
    'Muscle mass (lb)',
    'Hydration (lb)'
]]

# %%
# sanity check: compare to previously aggregated data for differences; source of diff should be understood
foo = weight_full.copy()
foo = pd.merge(foo, db_df.reset_index()[['date','weight']].rename({'weight':'wgt_db'}, axis=1), on='date', how='left')[['date', 'weight', 'wgt_db']]
foo['wgt_diff'] = abs(foo.weight-foo.wgt_db)

# %%
# most of these diffs stem from having multiple measurements on a day, and taking one versus the other
# however, on 2016-08-11: there is only one entry, and the latest pull from Withings shows 165.6, not 166.7. I'm ok with that.
foo[foo.wgt_diff>0.3]
# Out:
#            date  weight  wgt_db  wgt_diff
# 710  2014-12-12   178.5   178.0       0.5
# 824  2015-04-05   174.3   175.5       1.2
# 1317 2016-08-10   166.7   166.1       0.6
# 1318 2016-08-11   165.6   166.7       1.1

# %% [markdown]
# ### Export data to file

# %%
weight_full['date'] = [x.date() for x in weight_full['date']]
weight_full.to_csv(weight_full_file, index=False)

# %% [markdown]
# ## Food

# %%
client = myfitnesspal.Client('jamieinfinity')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-11-e3e64ee815d9> in <module>
# ----> 1 client = myfitnesspal.Client('jamieinfinity')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/myfitnesspal/client.py in __init__(self, username, password, login, unit_aware)
#      59         self.session = requests.Session()
#      60         if login:
# ---> 61             self._login()
#      62
#      63     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/myfitnesspal/client.py in _login(self)
#     114             raise MyfitnesspalLoginError()
#     115
# --> 116         self._auth_data = self._get_auth_data()
#     117         self._user_metadata = self._get_user_metadata()
#     118
#
# ~/opt/anaconda3/lib/python3.7/site-packages/myfitnesspal/client.py in _get_auth_data(self)
#     130             )
#     131
# --> 132         return result.json()
#     133
#     134     def _get_user_metadata(self) -> types.UserMetadata:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
start_date = datetime.datetime.strptime('2015-09-16', '%Y-%m-%d').date()
end_date = datetime.datetime.strptime('2021-01-24', '%Y-%m-%d').date()
num_days = (end_date - start_date).days+1

dates=[]
daily_totals = []
daily_meal_totals = []
daily_diary = []
for d in range(num_days):
    dq = end_date - datetime.timedelta(days=d)
    print((round(d/num_days, 2), dq))
    data = client.get_date(dq)

    dates.append(dq)
    daily_totals.append(data.totals)
    daily_meal_totals.append([x.totals for x in data.meals])
    daily_diary.append(data.get_as_dict())
# Out:
# (0.0, datetime.date(2021, 1, 24))
# (0.0, datetime.date(2021, 1, 23))
# (0.0, datetime.date(2021, 1, 22))
# (0.0, datetime.date(2021, 1, 21))
# (0.0, datetime.date(2021, 1, 20))
# (0.0, datetime.date(2021, 1, 19))
# (0.0, datetime.date(2021, 1, 18))
# (0.0, datetime.date(2021, 1, 17))
# (0.0, datetime.date(2021, 1, 16))
# (0.0, datetime.date(2021, 1, 15))
# (0.01, datetime.date(2021, 1, 14))
# (0.01, datetime.date(2021, 1, 13))
# (0.01, datetime.date(2021, 1, 12))
# (0.01, datetime.date(2021, 1, 11))
# (0.01, datetime.date(2021, 1, 10))
# (0.01, datetime.date(2021, 1, 9))
# (0.01, datetime.date(2021, 1, 8))
# (0.01, datetime.date(2021, 1, 7))
# (0.01, datetime.date(2021, 1, 6))
# (0.01, datetime.date(2021, 1, 5))
# (0.01, datetime.date(2021, 1, 4))
# (0.01, datetime.date(2021, 1, 3))
# (0.01, datetime.date(2021, 1, 2))
# (0.01, datetime.date(2021, 1, 1))
# (0.01, datetime.date(2020, 12, 31))
# (0.01, datetime.date(2020, 12, 30))
# (0.01, datetime.date(2020, 12, 29))
# (0.01, datetime.date(2020, 12, 28))
# (0.01, datetime.date(2020, 12, 27))
# (0.01, datetime.date(2020, 12, 26))
# (0.02, datetime.date(2020, 12, 25))
# (0.02, datetime.date(2020, 12, 24))
# (0.02, datetime.date(2020, 12, 23))
# (0.02, datetime.date(2020, 12, 22))
# (0.02, datetime.date(2020, 12, 21))
# (0.02, datetime.date(2020, 12, 20))
# (0.02, datetime.date(2020, 12, 19))
# (0.02, datetime.date(2020, 12, 18))
# (0.02, datetime.date(2020, 12, 17))
# (0.02, datetime.date(2020, 12, 16))
# (0.02, datetime.date(2020, 12, 15))
# (0.02, datetime.date(2020, 12, 14))
# (0.02, datetime.date(2020, 12, 13))
# (0.02, datetime.date(2020, 12, 12))
# (0.02, datetime.date(2020, 12, 11))
# (0.02, datetime.date(2020, 12, 10))
# (0.02, datetime.date(2020, 12, 9))
# (0.02, datetime.date(2020, 12, 8))
# (0.02, datetime.date(2020, 12, 7))
# (0.03, datetime.date(2020, 12, 6))
# (0.03, datetime.date(2020, 12, 5))
# (0.03, datetime.date(2020, 12, 4))
# (0.03, datetime.date(2020, 12, 3))
# (0.03, datetime.date(2020, 12, 2))
# (0.03, datetime.date(2020, 12, 1))
# (0.03, datetime.date(2020, 11, 30))
# (0.03, datetime.date(2020, 11, 29))
# (0.03, datetime.date(2020, 11, 28))
# (0.03, datetime.date(2020, 11, 27))
# (0.03, datetime.date(2020, 11, 26))
# (0.03, datetime.date(2020, 11, 25))
# (0.03, datetime.date(2020, 11, 24))
# (0.03, datetime.date(2020, 11, 23))
# (0.03, datetime.date(2020, 11, 22))
# (0.03, datetime.date(2020, 11, 21))
# (0.03, datetime.date(2020, 11, 20))
# (0.03, datetime.date(2020, 11, 19))
# (0.03, datetime.date(2020, 11, 18))
# (0.03, datetime.date(2020, 11, 17))
# (0.04, datetime.date(2020, 11, 16))
# (0.04, datetime.date(2020, 11, 15))
# (0.04, datetime.date(2020, 11, 14))
# (0.04, datetime.date(2020, 11, 13))
# (0.04, datetime.date(2020, 11, 12))
# (0.04, datetime.date(2020, 11, 11))
# (0.04, datetime.date(2020, 11, 10))
# (0.04, datetime.date(2020, 11, 9))
# (0.04, datetime.date(2020, 11, 8))
# (0.04, datetime.date(2020, 11, 7))
# (0.04, datetime.date(2020, 11, 6))
# (0.04, datetime.date(2020, 11, 5))
# (0.04, datetime.date(2020, 11, 4))
# (0.04, datetime.date(2020, 11, 3))
# (0.04, datetime.date(2020, 11, 2))
# (0.04, datetime.date(2020, 11, 1))
# (0.04, datetime.date(2020, 10, 31))
# (0.04, datetime.date(2020, 10, 30))
# (0.04, datetime.date(2020, 10, 29))
# (0.04, datetime.date(2020, 10, 28))
# (0.05, datetime.date(2020, 10, 27))
# (0.05, datetime.date(2020, 10, 26))
# (0.05, datetime.date(2020, 10, 25))
# (0.05, datetime.date(2020, 10, 24))
# (0.05, datetime.date(2020, 10, 23))
# (0.05, datetime.date(2020, 10, 22))
# (0.05, datetime.date(2020, 10, 21))
# (0.05, datetime.date(2020, 10, 20))
# (0.05, datetime.date(2020, 10, 19))
# (0.05, datetime.date(2020, 10, 18))
# (0.05, datetime.date(2020, 10, 17))
# (0.05, datetime.date(2020, 10, 16))
# (0.05, datetime.date(2020, 10, 15))
# (0.05, datetime.date(2020, 10, 14))
# (0.05, datetime.date(2020, 10, 13))
# (0.05, datetime.date(2020, 10, 12))
# (0.05, datetime.date(2020, 10, 11))
# (0.05, datetime.date(2020, 10, 10))
# (0.05, datetime.date(2020, 10, 9))
# (0.06, datetime.date(2020, 10, 8))
# (0.06, datetime.date(2020, 10, 7))
# (0.06, datetime.date(2020, 10, 6))
# (0.06, datetime.date(2020, 10, 5))
# (0.06, datetime.date(2020, 10, 4))
# (0.06, datetime.date(2020, 10, 3))
# (0.06, datetime.date(2020, 10, 2))
# (0.06, datetime.date(2020, 10, 1))
# (0.06, datetime.date(2020, 9, 30))
# (0.06, datetime.date(2020, 9, 29))
# (0.06, datetime.date(2020, 9, 28))
# (0.06, datetime.date(2020, 9, 27))
# (0.06, datetime.date(2020, 9, 26))
# (0.06, datetime.date(2020, 9, 25))
# (0.06, datetime.date(2020, 9, 24))
# (0.06, datetime.date(2020, 9, 23))
# (0.06, datetime.date(2020, 9, 22))
# (0.06, datetime.date(2020, 9, 21))
# (0.06, datetime.date(2020, 9, 20))
# (0.06, datetime.date(2020, 9, 19))
# (0.07, datetime.date(2020, 9, 18))
# (0.07, datetime.date(2020, 9, 17))
# (0.07, datetime.date(2020, 9, 16))
# (0.07, datetime.date(2020, 9, 15))
# (0.07, datetime.date(2020, 9, 14))
# (0.07, datetime.date(2020, 9, 13))
# (0.07, datetime.date(2020, 9, 12))
# (0.07, datetime.date(2020, 9, 11))
# (0.07, datetime.date(2020, 9, 10))
# (0.07, datetime.date(2020, 9, 9))
# (0.07, datetime.date(2020, 9, 8))
# (0.07, datetime.date(2020, 9, 7))
# (0.07, datetime.date(2020, 9, 6))
# (0.07, datetime.date(2020, 9, 5))
# (0.07, datetime.date(2020, 9, 4))
# (0.07, datetime.date(2020, 9, 3))
# (0.07, datetime.date(2020, 9, 2))
# (0.07, datetime.date(2020, 9, 1))
# (0.07, datetime.date(2020, 8, 31))
# (0.08, datetime.date(2020, 8, 30))
# (0.08, datetime.date(2020, 8, 29))
# (0.08, datetime.date(2020, 8, 28))
# (0.08, datetime.date(2020, 8, 27))
# (0.08, datetime.date(2020, 8, 26))
# (0.08, datetime.date(2020, 8, 25))
# (0.08, datetime.date(2020, 8, 24))
# (0.08, datetime.date(2020, 8, 23))
# (0.08, datetime.date(2020, 8, 22))
# (0.08, datetime.date(2020, 8, 21))
# (0.08, datetime.date(2020, 8, 20))
# (0.08, datetime.date(2020, 8, 19))
# (0.08, datetime.date(2020, 8, 18))
# (0.08, datetime.date(2020, 8, 17))
# (0.08, datetime.date(2020, 8, 16))
# (0.08, datetime.date(2020, 8, 15))
# (0.08, datetime.date(2020, 8, 14))
# (0.08, datetime.date(2020, 8, 13))
# (0.08, datetime.date(2020, 8, 12))
# (0.08, datetime.date(2020, 8, 11))
# (0.09, datetime.date(2020, 8, 10))
# (0.09, datetime.date(2020, 8, 9))
# (0.09, datetime.date(2020, 8, 8))
# (0.09, datetime.date(2020, 8, 7))
# (0.09, datetime.date(2020, 8, 6))
# (0.09, datetime.date(2020, 8, 5))
# (0.09, datetime.date(2020, 8, 4))
# (0.09, datetime.date(2020, 8, 3))
# (0.09, datetime.date(2020, 8, 2))
# (0.09, datetime.date(2020, 8, 1))
# (0.09, datetime.date(2020, 7, 31))
# (0.09, datetime.date(2020, 7, 30))
# (0.09, datetime.date(2020, 7, 29))
# (0.09, datetime.date(2020, 7, 28))
# (0.09, datetime.date(2020, 7, 27))
# (0.09, datetime.date(2020, 7, 26))
# (0.09, datetime.date(2020, 7, 25))
# (0.09, datetime.date(2020, 7, 24))
# (0.09, datetime.date(2020, 7, 23))
# (0.09, datetime.date(2020, 7, 22))
# (0.1, datetime.date(2020, 7, 21))
# (0.1, datetime.date(2020, 7, 20))
# (0.1, datetime.date(2020, 7, 19))
# (0.1, datetime.date(2020, 7, 18))
# (0.1, datetime.date(2020, 7, 17))
# (0.1, datetime.date(2020, 7, 16))
# (0.1, datetime.date(2020, 7, 15))
# (0.1, datetime.date(2020, 7, 14))
# (0.1, datetime.date(2020, 7, 13))
# (0.1, datetime.date(2020, 7, 12))
# (0.1, datetime.date(2020, 7, 11))
# (0.1, datetime.date(2020, 7, 10))
# (0.1, datetime.date(2020, 7, 9))
# (0.1, datetime.date(2020, 7, 8))
# (0.1, datetime.date(2020, 7, 7))
# (0.1, datetime.date(2020, 7, 6))
# (0.1, datetime.date(2020, 7, 5))
# (0.1, datetime.date(2020, 7, 4))
# (0.1, datetime.date(2020, 7, 3))
# (0.11, datetime.date(2020, 7, 2))
# (0.11, datetime.date(2020, 7, 1))
# (0.11, datetime.date(2020, 6, 30))
# (0.11, datetime.date(2020, 6, 29))
# (0.11, datetime.date(2020, 6, 28))
# (0.11, datetime.date(2020, 6, 27))
# (0.11, datetime.date(2020, 6, 26))
# (0.11, datetime.date(2020, 6, 25))
# (0.11, datetime.date(2020, 6, 24))
# (0.11, datetime.date(2020, 6, 23))
# (0.11, datetime.date(2020, 6, 22))
# (0.11, datetime.date(2020, 6, 21))
# (0.11, datetime.date(2020, 6, 20))
# (0.11, datetime.date(2020, 6, 19))
# (0.11, datetime.date(2020, 6, 18))
# (0.11, datetime.date(2020, 6, 17))
# (0.11, datetime.date(2020, 6, 16))
# (0.11, datetime.date(2020, 6, 15))
# (0.11, datetime.date(2020, 6, 14))
# (0.11, datetime.date(2020, 6, 13))
# (0.12, datetime.date(2020, 6, 12))
# (0.12, datetime.date(2020, 6, 11))
# (0.12, datetime.date(2020, 6, 10))
# (0.12, datetime.date(2020, 6, 9))
# (0.12, datetime.date(2020, 6, 8))
# (0.12, datetime.date(2020, 6, 7))
# (0.12, datetime.date(2020, 6, 6))
# (0.12, datetime.date(2020, 6, 5))
# (0.12, datetime.date(2020, 6, 4))
# (0.12, datetime.date(2020, 6, 3))
# (0.12, datetime.date(2020, 6, 2))
# (0.12, datetime.date(2020, 6, 1))
# (0.12, datetime.date(2020, 5, 31))
# (0.12, datetime.date(2020, 5, 30))
# (0.12, datetime.date(2020, 5, 29))
# (0.12, datetime.date(2020, 5, 28))
# (0.12, datetime.date(2020, 5, 27))
# (0.12, datetime.date(2020, 5, 26))
# (0.12, datetime.date(2020, 5, 25))
# (0.13, datetime.date(2020, 5, 24))
# (0.13, datetime.date(2020, 5, 23))
# (0.13, datetime.date(2020, 5, 22))
# (0.13, datetime.date(2020, 5, 21))
# (0.13, datetime.date(2020, 5, 20))
# (0.13, datetime.date(2020, 5, 19))
# (0.13, datetime.date(2020, 5, 18))
# (0.13, datetime.date(2020, 5, 17))
# (0.13, datetime.date(2020, 5, 16))
# (0.13, datetime.date(2020, 5, 15))
# (0.13, datetime.date(2020, 5, 14))
# (0.13, datetime.date(2020, 5, 13))
# (0.13, datetime.date(2020, 5, 12))
# (0.13, datetime.date(2020, 5, 11))
# (0.13, datetime.date(2020, 5, 10))
# (0.13, datetime.date(2020, 5, 9))
# (0.13, datetime.date(2020, 5, 8))
# (0.13, datetime.date(2020, 5, 7))
# (0.13, datetime.date(2020, 5, 6))
# (0.13, datetime.date(2020, 5, 5))
# (0.14, datetime.date(2020, 5, 4))
# (0.14, datetime.date(2020, 5, 3))
# (0.14, datetime.date(2020, 5, 2))
# (0.14, datetime.date(2020, 5, 1))
# (0.14, datetime.date(2020, 4, 30))
# (0.14, datetime.date(2020, 4, 29))
# (0.14, datetime.date(2020, 4, 28))
# (0.14, datetime.date(2020, 4, 27))
# (0.14, datetime.date(2020, 4, 26))
# (0.14, datetime.date(2020, 4, 25))
# (0.14, datetime.date(2020, 4, 24))
# (0.14, datetime.date(2020, 4, 23))
# (0.14, datetime.date(2020, 4, 22))
# (0.14, datetime.date(2020, 4, 21))
# (0.14, datetime.date(2020, 4, 20))
# (0.14, datetime.date(2020, 4, 19))
# (0.14, datetime.date(2020, 4, 18))
# (0.14, datetime.date(2020, 4, 17))
# (0.14, datetime.date(2020, 4, 16))
# (0.15, datetime.date(2020, 4, 15))
# (0.15, datetime.date(2020, 4, 14))
# (0.15, datetime.date(2020, 4, 13))
# (0.15, datetime.date(2020, 4, 12))
# (0.15, datetime.date(2020, 4, 11))
# (0.15, datetime.date(2020, 4, 10))
# (0.15, datetime.date(2020, 4, 9))
# (0.15, datetime.date(2020, 4, 8))
# (0.15, datetime.date(2020, 4, 7))
# (0.15, datetime.date(2020, 4, 6))
# (0.15, datetime.date(2020, 4, 5))
# (0.15, datetime.date(2020, 4, 4))
# (0.15, datetime.date(2020, 4, 3))
# (0.15, datetime.date(2020, 4, 2))
# (0.15, datetime.date(2020, 4, 1))
# (0.15, datetime.date(2020, 3, 31))
# (0.15, datetime.date(2020, 3, 30))
# (0.15, datetime.date(2020, 3, 29))
# (0.15, datetime.date(2020, 3, 28))
# (0.15, datetime.date(2020, 3, 27))
# (0.16, datetime.date(2020, 3, 26))
# (0.16, datetime.date(2020, 3, 25))
# (0.16, datetime.date(2020, 3, 24))
# (0.16, datetime.date(2020, 3, 23))
# (0.16, datetime.date(2020, 3, 22))
# (0.16, datetime.date(2020, 3, 21))
# (0.16, datetime.date(2020, 3, 20))
# (0.16, datetime.date(2020, 3, 19))
# (0.16, datetime.date(2020, 3, 18))
# (0.16, datetime.date(2020, 3, 17))
# (0.16, datetime.date(2020, 3, 16))
# (0.16, datetime.date(2020, 3, 15))
# (0.16, datetime.date(2020, 3, 14))
# (0.16, datetime.date(2020, 3, 13))
# (0.16, datetime.date(2020, 3, 12))
# (0.16, datetime.date(2020, 3, 11))
# (0.16, datetime.date(2020, 3, 10))
# (0.16, datetime.date(2020, 3, 9))
# (0.16, datetime.date(2020, 3, 8))
# (0.16, datetime.date(2020, 3, 7))
# (0.17, datetime.date(2020, 3, 6))
# (0.17, datetime.date(2020, 3, 5))
# (0.17, datetime.date(2020, 3, 4))
# (0.17, datetime.date(2020, 3, 3))
# (0.17, datetime.date(2020, 3, 2))
# (0.17, datetime.date(2020, 3, 1))
# (0.17, datetime.date(2020, 2, 29))
# (0.17, datetime.date(2020, 2, 28))
# (0.17, datetime.date(2020, 2, 27))
# (0.17, datetime.date(2020, 2, 26))
# (0.17, datetime.date(2020, 2, 25))
# (0.17, datetime.date(2020, 2, 24))
# (0.17, datetime.date(2020, 2, 23))
# (0.17, datetime.date(2020, 2, 22))
# (0.17, datetime.date(2020, 2, 21))
# (0.17, datetime.date(2020, 2, 20))
# (0.17, datetime.date(2020, 2, 19))
# (0.17, datetime.date(2020, 2, 18))
# (0.17, datetime.date(2020, 2, 17))
# (0.18, datetime.date(2020, 2, 16))
# (0.18, datetime.date(2020, 2, 15))
# (0.18, datetime.date(2020, 2, 14))
# (0.18, datetime.date(2020, 2, 13))
# (0.18, datetime.date(2020, 2, 12))
# (0.18, datetime.date(2020, 2, 11))
# (0.18, datetime.date(2020, 2, 10))
# (0.18, datetime.date(2020, 2, 9))
# (0.18, datetime.date(2020, 2, 8))
# (0.18, datetime.date(2020, 2, 7))
# (0.18, datetime.date(2020, 2, 6))
# (0.18, datetime.date(2020, 2, 5))
# (0.18, datetime.date(2020, 2, 4))
# (0.18, datetime.date(2020, 2, 3))
# (0.18, datetime.date(2020, 2, 2))
# (0.18, datetime.date(2020, 2, 1))
# (0.18, datetime.date(2020, 1, 31))
# (0.18, datetime.date(2020, 1, 30))
# (0.18, datetime.date(2020, 1, 29))
# (0.18, datetime.date(2020, 1, 28))
# (0.19, datetime.date(2020, 1, 27))
# (0.19, datetime.date(2020, 1, 26))
# (0.19, datetime.date(2020, 1, 25))
# (0.19, datetime.date(2020, 1, 24))
# (0.19, datetime.date(2020, 1, 23))
# (0.19, datetime.date(2020, 1, 22))
# (0.19, datetime.date(2020, 1, 21))
# (0.19, datetime.date(2020, 1, 20))
# (0.19, datetime.date(2020, 1, 19))
# (0.19, datetime.date(2020, 1, 18))
# (0.19, datetime.date(2020, 1, 17))
# (0.19, datetime.date(2020, 1, 16))
# (0.19, datetime.date(2020, 1, 15))
# (0.19, datetime.date(2020, 1, 14))
# (0.19, datetime.date(2020, 1, 13))
# (0.19, datetime.date(2020, 1, 12))
# (0.19, datetime.date(2020, 1, 11))
# (0.19, datetime.date(2020, 1, 10))
# (0.19, datetime.date(2020, 1, 9))
# (0.2, datetime.date(2020, 1, 8))
# (0.2, datetime.date(2020, 1, 7))
# (0.2, datetime.date(2020, 1, 6))
# (0.2, datetime.date(2020, 1, 5))
# (0.2, datetime.date(2020, 1, 4))
# (0.2, datetime.date(2020, 1, 3))
# (0.2, datetime.date(2020, 1, 2))
# (0.2, datetime.date(2020, 1, 1))
# (0.2, datetime.date(2019, 12, 31))
# (0.2, datetime.date(2019, 12, 30))
# (0.2, datetime.date(2019, 12, 29))
# (0.2, datetime.date(2019, 12, 28))
# (0.2, datetime.date(2019, 12, 27))
# (0.2, datetime.date(2019, 12, 26))
# (0.2, datetime.date(2019, 12, 25))
# (0.2, datetime.date(2019, 12, 24))
# (0.2, datetime.date(2019, 12, 23))
# (0.2, datetime.date(2019, 12, 22))
# (0.2, datetime.date(2019, 12, 21))
# (0.2, datetime.date(2019, 12, 20))
# (0.21, datetime.date(2019, 12, 19))
# (0.21, datetime.date(2019, 12, 18))
# (0.21, datetime.date(2019, 12, 17))
# (0.21, datetime.date(2019, 12, 16))
# (0.21, datetime.date(2019, 12, 15))
# (0.21, datetime.date(2019, 12, 14))
# (0.21, datetime.date(2019, 12, 13))
# (0.21, datetime.date(2019, 12, 12))
# (0.21, datetime.date(2019, 12, 11))
# (0.21, datetime.date(2019, 12, 10))
# (0.21, datetime.date(2019, 12, 9))
# (0.21, datetime.date(2019, 12, 8))
# (0.21, datetime.date(2019, 12, 7))
# (0.21, datetime.date(2019, 12, 6))
# (0.21, datetime.date(2019, 12, 5))
# (0.21, datetime.date(2019, 12, 4))
# (0.21, datetime.date(2019, 12, 3))
# (0.21, datetime.date(2019, 12, 2))
# (0.21, datetime.date(2019, 12, 1))
# (0.22, datetime.date(2019, 11, 30))
# (0.22, datetime.date(2019, 11, 29))
# (0.22, datetime.date(2019, 11, 28))
# (0.22, datetime.date(2019, 11, 27))
# (0.22, datetime.date(2019, 11, 26))
# (0.22, datetime.date(2019, 11, 25))
# (0.22, datetime.date(2019, 11, 24))
# (0.22, datetime.date(2019, 11, 23))
# (0.22, datetime.date(2019, 11, 22))
# (0.22, datetime.date(2019, 11, 21))
# (0.22, datetime.date(2019, 11, 20))
# (0.22, datetime.date(2019, 11, 19))
# (0.22, datetime.date(2019, 11, 18))
# (0.22, datetime.date(2019, 11, 17))
# (0.22, datetime.date(2019, 11, 16))
# (0.22, datetime.date(2019, 11, 15))
# (0.22, datetime.date(2019, 11, 14))
# (0.22, datetime.date(2019, 11, 13))
# (0.22, datetime.date(2019, 11, 12))
# (0.22, datetime.date(2019, 11, 11))
# (0.23, datetime.date(2019, 11, 10))
# (0.23, datetime.date(2019, 11, 9))
# (0.23, datetime.date(2019, 11, 8))
# (0.23, datetime.date(2019, 11, 7))
# (0.23, datetime.date(2019, 11, 6))
# (0.23, datetime.date(2019, 11, 5))
# (0.23, datetime.date(2019, 11, 4))
# (0.23, datetime.date(2019, 11, 3))
# (0.23, datetime.date(2019, 11, 2))
# (0.23, datetime.date(2019, 11, 1))
# (0.23, datetime.date(2019, 10, 31))
# (0.23, datetime.date(2019, 10, 30))
# (0.23, datetime.date(2019, 10, 29))
# (0.23, datetime.date(2019, 10, 28))
# (0.23, datetime.date(2019, 10, 27))
# (0.23, datetime.date(2019, 10, 26))
# (0.23, datetime.date(2019, 10, 25))
# (0.23, datetime.date(2019, 10, 24))
# (0.23, datetime.date(2019, 10, 23))
# (0.23, datetime.date(2019, 10, 22))
# (0.24, datetime.date(2019, 10, 21))
# (0.24, datetime.date(2019, 10, 20))
# (0.24, datetime.date(2019, 10, 19))
# (0.24, datetime.date(2019, 10, 18))
# (0.24, datetime.date(2019, 10, 17))
# (0.24, datetime.date(2019, 10, 16))
# (0.24, datetime.date(2019, 10, 15))
# (0.24, datetime.date(2019, 10, 14))
# (0.24, datetime.date(2019, 10, 13))
# (0.24, datetime.date(2019, 10, 12))
# (0.24, datetime.date(2019, 10, 11))
# (0.24, datetime.date(2019, 10, 10))
# (0.24, datetime.date(2019, 10, 9))
# (0.24, datetime.date(2019, 10, 8))
# (0.24, datetime.date(2019, 10, 7))
# (0.24, datetime.date(2019, 10, 6))
# (0.24, datetime.date(2019, 10, 5))
# (0.24, datetime.date(2019, 10, 4))
# (0.24, datetime.date(2019, 10, 3))
# (0.25, datetime.date(2019, 10, 2))
# (0.25, datetime.date(2019, 10, 1))
# (0.25, datetime.date(2019, 9, 30))
# (0.25, datetime.date(2019, 9, 29))
# (0.25, datetime.date(2019, 9, 28))
# (0.25, datetime.date(2019, 9, 27))
# (0.25, datetime.date(2019, 9, 26))
# (0.25, datetime.date(2019, 9, 25))
# (0.25, datetime.date(2019, 9, 24))
# (0.25, datetime.date(2019, 9, 23))
# (0.25, datetime.date(2019, 9, 22))
# (0.25, datetime.date(2019, 9, 21))
# (0.25, datetime.date(2019, 9, 20))
# (0.25, datetime.date(2019, 9, 19))
# (0.25, datetime.date(2019, 9, 18))
# (0.25, datetime.date(2019, 9, 17))
# (0.25, datetime.date(2019, 9, 16))
# (0.25, datetime.date(2019, 9, 15))
# (0.25, datetime.date(2019, 9, 14))
# (0.25, datetime.date(2019, 9, 13))
# (0.26, datetime.date(2019, 9, 12))
# (0.26, datetime.date(2019, 9, 11))
# (0.26, datetime.date(2019, 9, 10))
# (0.26, datetime.date(2019, 9, 9))
# (0.26, datetime.date(2019, 9, 8))
# (0.26, datetime.date(2019, 9, 7))
# (0.26, datetime.date(2019, 9, 6))
# (0.26, datetime.date(2019, 9, 5))
# (0.26, datetime.date(2019, 9, 4))
# (0.26, datetime.date(2019, 9, 3))
# (0.26, datetime.date(2019, 9, 2))
# (0.26, datetime.date(2019, 9, 1))
# (0.26, datetime.date(2019, 8, 31))
# (0.26, datetime.date(2019, 8, 30))
# (0.26, datetime.date(2019, 8, 29))
# (0.26, datetime.date(2019, 8, 28))
# (0.26, datetime.date(2019, 8, 27))
# (0.26, datetime.date(2019, 8, 26))
# (0.26, datetime.date(2019, 8, 25))
# (0.27, datetime.date(2019, 8, 24))
# (0.27, datetime.date(2019, 8, 23))
# (0.27, datetime.date(2019, 8, 22))
# (0.27, datetime.date(2019, 8, 21))
# (0.27, datetime.date(2019, 8, 20))
# (0.27, datetime.date(2019, 8, 19))
# (0.27, datetime.date(2019, 8, 18))
# (0.27, datetime.date(2019, 8, 17))
# (0.27, datetime.date(2019, 8, 16))
# (0.27, datetime.date(2019, 8, 15))
# (0.27, datetime.date(2019, 8, 14))
# (0.27, datetime.date(2019, 8, 13))
# (0.27, datetime.date(2019, 8, 12))
# (0.27, datetime.date(2019, 8, 11))
# (0.27, datetime.date(2019, 8, 10))
# (0.27, datetime.date(2019, 8, 9))
# (0.27, datetime.date(2019, 8, 8))
# (0.27, datetime.date(2019, 8, 7))
# (0.27, datetime.date(2019, 8, 6))
# (0.27, datetime.date(2019, 8, 5))
# (0.28, datetime.date(2019, 8, 4))
# (0.28, datetime.date(2019, 8, 3))
# (0.28, datetime.date(2019, 8, 2))
# (0.28, datetime.date(2019, 8, 1))
# (0.28, datetime.date(2019, 7, 31))
# (0.28, datetime.date(2019, 7, 30))
# (0.28, datetime.date(2019, 7, 29))
# (0.28, datetime.date(2019, 7, 28))
# (0.28, datetime.date(2019, 7, 27))
# (0.28, datetime.date(2019, 7, 26))
# (0.28, datetime.date(2019, 7, 25))
# (0.28, datetime.date(2019, 7, 24))
# (0.28, datetime.date(2019, 7, 23))
# (0.28, datetime.date(2019, 7, 22))
# (0.28, datetime.date(2019, 7, 21))
# (0.28, datetime.date(2019, 7, 20))
# (0.28, datetime.date(2019, 7, 19))
# (0.28, datetime.date(2019, 7, 18))
# (0.28, datetime.date(2019, 7, 17))
# (0.28, datetime.date(2019, 7, 16))
# (0.29, datetime.date(2019, 7, 15))
# (0.29, datetime.date(2019, 7, 14))
# (0.29, datetime.date(2019, 7, 13))
# (0.29, datetime.date(2019, 7, 12))
# (0.29, datetime.date(2019, 7, 11))
# (0.29, datetime.date(2019, 7, 10))
# (0.29, datetime.date(2019, 7, 9))
# (0.29, datetime.date(2019, 7, 8))
# (0.29, datetime.date(2019, 7, 7))
# (0.29, datetime.date(2019, 7, 6))
# (0.29, datetime.date(2019, 7, 5))
# (0.29, datetime.date(2019, 7, 4))
# (0.29, datetime.date(2019, 7, 3))
# (0.29, datetime.date(2019, 7, 2))
# (0.29, datetime.date(2019, 7, 1))
# (0.29, datetime.date(2019, 6, 30))
# (0.29, datetime.date(2019, 6, 29))
# (0.29, datetime.date(2019, 6, 28))
# (0.29, datetime.date(2019, 6, 27))
# (0.3, datetime.date(2019, 6, 26))
# (0.3, datetime.date(2019, 6, 25))
# (0.3, datetime.date(2019, 6, 24))
# (0.3, datetime.date(2019, 6, 23))
# (0.3, datetime.date(2019, 6, 22))
# (0.3, datetime.date(2019, 6, 21))
# (0.3, datetime.date(2019, 6, 20))
# (0.3, datetime.date(2019, 6, 19))
# (0.3, datetime.date(2019, 6, 18))
# (0.3, datetime.date(2019, 6, 17))
# (0.3, datetime.date(2019, 6, 16))
# (0.3, datetime.date(2019, 6, 15))
# (0.3, datetime.date(2019, 6, 14))
# (0.3, datetime.date(2019, 6, 13))
# (0.3, datetime.date(2019, 6, 12))
# (0.3, datetime.date(2019, 6, 11))
# (0.3, datetime.date(2019, 6, 10))
# (0.3, datetime.date(2019, 6, 9))
# (0.3, datetime.date(2019, 6, 8))
# (0.3, datetime.date(2019, 6, 7))
# (0.31, datetime.date(2019, 6, 6))
# (0.31, datetime.date(2019, 6, 5))
# (0.31, datetime.date(2019, 6, 4))
# (0.31, datetime.date(2019, 6, 3))
# (0.31, datetime.date(2019, 6, 2))
# (0.31, datetime.date(2019, 6, 1))
# (0.31, datetime.date(2019, 5, 31))
# (0.31, datetime.date(2019, 5, 30))
# (0.31, datetime.date(2019, 5, 29))
# (0.31, datetime.date(2019, 5, 28))
# (0.31, datetime.date(2019, 5, 27))
# (0.31, datetime.date(2019, 5, 26))
# (0.31, datetime.date(2019, 5, 25))
# (0.31, datetime.date(2019, 5, 24))
# (0.31, datetime.date(2019, 5, 23))
# (0.31, datetime.date(2019, 5, 22))
# (0.31, datetime.date(2019, 5, 21))
# (0.31, datetime.date(2019, 5, 20))
# (0.31, datetime.date(2019, 5, 19))
# (0.32, datetime.date(2019, 5, 18))
# (0.32, datetime.date(2019, 5, 17))
# (0.32, datetime.date(2019, 5, 16))
# (0.32, datetime.date(2019, 5, 15))
# (0.32, datetime.date(2019, 5, 14))
# (0.32, datetime.date(2019, 5, 13))
# (0.32, datetime.date(2019, 5, 12))
# (0.32, datetime.date(2019, 5, 11))
# (0.32, datetime.date(2019, 5, 10))
# (0.32, datetime.date(2019, 5, 9))
# (0.32, datetime.date(2019, 5, 8))
# (0.32, datetime.date(2019, 5, 7))
# (0.32, datetime.date(2019, 5, 6))
# (0.32, datetime.date(2019, 5, 5))
# (0.32, datetime.date(2019, 5, 4))
# (0.32, datetime.date(2019, 5, 3))
# (0.32, datetime.date(2019, 5, 2))
# (0.32, datetime.date(2019, 5, 1))
# (0.32, datetime.date(2019, 4, 30))
# (0.32, datetime.date(2019, 4, 29))
# (0.33, datetime.date(2019, 4, 28))
# (0.33, datetime.date(2019, 4, 27))
# (0.33, datetime.date(2019, 4, 26))
# (0.33, datetime.date(2019, 4, 25))
# (0.33, datetime.date(2019, 4, 24))
# (0.33, datetime.date(2019, 4, 23))
# (0.33, datetime.date(2019, 4, 22))
# (0.33, datetime.date(2019, 4, 21))
# (0.33, datetime.date(2019, 4, 20))
# (0.33, datetime.date(2019, 4, 19))
# (0.33, datetime.date(2019, 4, 18))
# (0.33, datetime.date(2019, 4, 17))
# (0.33, datetime.date(2019, 4, 16))
# (0.33, datetime.date(2019, 4, 15))
# (0.33, datetime.date(2019, 4, 14))
# (0.33, datetime.date(2019, 4, 13))
# (0.33, datetime.date(2019, 4, 12))
# (0.33, datetime.date(2019, 4, 11))
# (0.33, datetime.date(2019, 4, 10))
# (0.34, datetime.date(2019, 4, 9))
# (0.34, datetime.date(2019, 4, 8))
# (0.34, datetime.date(2019, 4, 7))
# (0.34, datetime.date(2019, 4, 6))
# (0.34, datetime.date(2019, 4, 5))
# (0.34, datetime.date(2019, 4, 4))
# (0.34, datetime.date(2019, 4, 3))
# (0.34, datetime.date(2019, 4, 2))
# (0.34, datetime.date(2019, 4, 1))
# (0.34, datetime.date(2019, 3, 31))
# (0.34, datetime.date(2019, 3, 30))
# (0.34, datetime.date(2019, 3, 29))
# (0.34, datetime.date(2019, 3, 28))
# (0.34, datetime.date(2019, 3, 27))
# (0.34, datetime.date(2019, 3, 26))
# (0.34, datetime.date(2019, 3, 25))
# (0.34, datetime.date(2019, 3, 24))
# (0.34, datetime.date(2019, 3, 23))
# (0.34, datetime.date(2019, 3, 22))
# (0.34, datetime.date(2019, 3, 21))
# (0.35, datetime.date(2019, 3, 20))
# (0.35, datetime.date(2019, 3, 19))
# (0.35, datetime.date(2019, 3, 18))
# (0.35, datetime.date(2019, 3, 17))
# (0.35, datetime.date(2019, 3, 16))
# (0.35, datetime.date(2019, 3, 15))
# (0.35, datetime.date(2019, 3, 14))
# (0.35, datetime.date(2019, 3, 13))
# (0.35, datetime.date(2019, 3, 12))
# (0.35, datetime.date(2019, 3, 11))
# (0.35, datetime.date(2019, 3, 10))
# (0.35, datetime.date(2019, 3, 9))
# (0.35, datetime.date(2019, 3, 8))
# (0.35, datetime.date(2019, 3, 7))
# (0.35, datetime.date(2019, 3, 6))
# (0.35, datetime.date(2019, 3, 5))
# (0.35, datetime.date(2019, 3, 4))
# (0.35, datetime.date(2019, 3, 3))
# (0.35, datetime.date(2019, 3, 2))
# (0.35, datetime.date(2019, 3, 1))
# (0.36, datetime.date(2019, 2, 28))
# (0.36, datetime.date(2019, 2, 27))
# (0.36, datetime.date(2019, 2, 26))
# (0.36, datetime.date(2019, 2, 25))
# (0.36, datetime.date(2019, 2, 24))
# (0.36, datetime.date(2019, 2, 23))
# (0.36, datetime.date(2019, 2, 22))
# (0.36, datetime.date(2019, 2, 21))
# (0.36, datetime.date(2019, 2, 20))
# (0.36, datetime.date(2019, 2, 19))
# (0.36, datetime.date(2019, 2, 18))
# (0.36, datetime.date(2019, 2, 17))
# (0.36, datetime.date(2019, 2, 16))
# (0.36, datetime.date(2019, 2, 15))
# (0.36, datetime.date(2019, 2, 14))
# (0.36, datetime.date(2019, 2, 13))
# (0.36, datetime.date(2019, 2, 12))
# (0.36, datetime.date(2019, 2, 11))
# (0.36, datetime.date(2019, 2, 10))
# (0.37, datetime.date(2019, 2, 9))
# (0.37, datetime.date(2019, 2, 8))
# (0.37, datetime.date(2019, 2, 7))
# (0.37, datetime.date(2019, 2, 6))
# (0.37, datetime.date(2019, 2, 5))
# (0.37, datetime.date(2019, 2, 4))
# (0.37, datetime.date(2019, 2, 3))
# (0.37, datetime.date(2019, 2, 2))
# (0.37, datetime.date(2019, 2, 1))
# (0.37, datetime.date(2019, 1, 31))
# (0.37, datetime.date(2019, 1, 30))
# (0.37, datetime.date(2019, 1, 29))
# (0.37, datetime.date(2019, 1, 28))
# (0.37, datetime.date(2019, 1, 27))
# (0.37, datetime.date(2019, 1, 26))
# (0.37, datetime.date(2019, 1, 25))
# (0.37, datetime.date(2019, 1, 24))
# (0.37, datetime.date(2019, 1, 23))
# (0.37, datetime.date(2019, 1, 22))
# (0.37, datetime.date(2019, 1, 21))
# (0.38, datetime.date(2019, 1, 20))
# (0.38, datetime.date(2019, 1, 19))
# (0.38, datetime.date(2019, 1, 18))
# (0.38, datetime.date(2019, 1, 17))
# (0.38, datetime.date(2019, 1, 16))
# (0.38, datetime.date(2019, 1, 15))
# (0.38, datetime.date(2019, 1, 14))
# (0.38, datetime.date(2019, 1, 13))
# (0.38, datetime.date(2019, 1, 12))
# (0.38, datetime.date(2019, 1, 11))
# (0.38, datetime.date(2019, 1, 10))
# (0.38, datetime.date(2019, 1, 9))
# (0.38, datetime.date(2019, 1, 8))
# (0.38, datetime.date(2019, 1, 7))
# (0.38, datetime.date(2019, 1, 6))
# (0.38, datetime.date(2019, 1, 5))
# (0.38, datetime.date(2019, 1, 4))
# (0.38, datetime.date(2019, 1, 3))
# (0.38, datetime.date(2019, 1, 2))
# (0.39, datetime.date(2019, 1, 1))
# (0.39, datetime.date(2018, 12, 31))
# (0.39, datetime.date(2018, 12, 30))
# (0.39, datetime.date(2018, 12, 29))
# (0.39, datetime.date(2018, 12, 28))
# (0.39, datetime.date(2018, 12, 27))
# (0.39, datetime.date(2018, 12, 26))
# (0.39, datetime.date(2018, 12, 25))
# (0.39, datetime.date(2018, 12, 24))
# (0.39, datetime.date(2018, 12, 23))
# (0.39, datetime.date(2018, 12, 22))
# (0.39, datetime.date(2018, 12, 21))
# (0.39, datetime.date(2018, 12, 20))
# (0.39, datetime.date(2018, 12, 19))
# (0.39, datetime.date(2018, 12, 18))
# (0.39, datetime.date(2018, 12, 17))
# (0.39, datetime.date(2018, 12, 16))
# (0.39, datetime.date(2018, 12, 15))
# (0.39, datetime.date(2018, 12, 14))
# (0.39, datetime.date(2018, 12, 13))
# (0.4, datetime.date(2018, 12, 12))
# (0.4, datetime.date(2018, 12, 11))
# (0.4, datetime.date(2018, 12, 10))
# (0.4, datetime.date(2018, 12, 9))
# (0.4, datetime.date(2018, 12, 8))
# (0.4, datetime.date(2018, 12, 7))
# (0.4, datetime.date(2018, 12, 6))
# (0.4, datetime.date(2018, 12, 5))
# (0.4, datetime.date(2018, 12, 4))
# (0.4, datetime.date(2018, 12, 3))
# (0.4, datetime.date(2018, 12, 2))
# (0.4, datetime.date(2018, 12, 1))
# (0.4, datetime.date(2018, 11, 30))
# (0.4, datetime.date(2018, 11, 29))
# (0.4, datetime.date(2018, 11, 28))
# (0.4, datetime.date(2018, 11, 27))
# (0.4, datetime.date(2018, 11, 26))
# (0.4, datetime.date(2018, 11, 25))
# (0.4, datetime.date(2018, 11, 24))
# (0.41, datetime.date(2018, 11, 23))
# (0.41, datetime.date(2018, 11, 22))
# (0.41, datetime.date(2018, 11, 21))
# (0.41, datetime.date(2018, 11, 20))
# (0.41, datetime.date(2018, 11, 19))
# (0.41, datetime.date(2018, 11, 18))
# (0.41, datetime.date(2018, 11, 17))
# (0.41, datetime.date(2018, 11, 16))
# (0.41, datetime.date(2018, 11, 15))
# (0.41, datetime.date(2018, 11, 14))
# (0.41, datetime.date(2018, 11, 13))
# (0.41, datetime.date(2018, 11, 12))
# (0.41, datetime.date(2018, 11, 11))
# (0.41, datetime.date(2018, 11, 10))
# (0.41, datetime.date(2018, 11, 9))
# (0.41, datetime.date(2018, 11, 8))
# (0.41, datetime.date(2018, 11, 7))
# (0.41, datetime.date(2018, 11, 6))
# (0.41, datetime.date(2018, 11, 5))
# (0.41, datetime.date(2018, 11, 4))
# (0.42, datetime.date(2018, 11, 3))
# (0.42, datetime.date(2018, 11, 2))
# (0.42, datetime.date(2018, 11, 1))
# (0.42, datetime.date(2018, 10, 31))
# (0.42, datetime.date(2018, 10, 30))
# (0.42, datetime.date(2018, 10, 29))
# (0.42, datetime.date(2018, 10, 28))
# (0.42, datetime.date(2018, 10, 27))
# (0.42, datetime.date(2018, 10, 26))
# (0.42, datetime.date(2018, 10, 25))
# (0.42, datetime.date(2018, 10, 24))
# (0.42, datetime.date(2018, 10, 23))
# (0.42, datetime.date(2018, 10, 22))
# (0.42, datetime.date(2018, 10, 21))
# (0.42, datetime.date(2018, 10, 20))
# (0.42, datetime.date(2018, 10, 19))
# (0.42, datetime.date(2018, 10, 18))
# (0.42, datetime.date(2018, 10, 17))
# (0.42, datetime.date(2018, 10, 16))
# (0.42, datetime.date(2018, 10, 15))
# (0.43, datetime.date(2018, 10, 14))
# (0.43, datetime.date(2018, 10, 13))
# (0.43, datetime.date(2018, 10, 12))
# (0.43, datetime.date(2018, 10, 11))
# (0.43, datetime.date(2018, 10, 10))
# (0.43, datetime.date(2018, 10, 9))
# (0.43, datetime.date(2018, 10, 8))
# (0.43, datetime.date(2018, 10, 7))
# (0.43, datetime.date(2018, 10, 6))
# (0.43, datetime.date(2018, 10, 5))
# (0.43, datetime.date(2018, 10, 4))
# (0.43, datetime.date(2018, 10, 3))
# (0.43, datetime.date(2018, 10, 2))
# (0.43, datetime.date(2018, 10, 1))
# (0.43, datetime.date(2018, 9, 30))
# (0.43, datetime.date(2018, 9, 29))
# (0.43, datetime.date(2018, 9, 28))
# (0.43, datetime.date(2018, 9, 27))
# (0.43, datetime.date(2018, 9, 26))
# (0.44, datetime.date(2018, 9, 25))
# (0.44, datetime.date(2018, 9, 24))
# (0.44, datetime.date(2018, 9, 23))
# (0.44, datetime.date(2018, 9, 22))
# (0.44, datetime.date(2018, 9, 21))
# (0.44, datetime.date(2018, 9, 20))
# (0.44, datetime.date(2018, 9, 19))
# (0.44, datetime.date(2018, 9, 18))
# (0.44, datetime.date(2018, 9, 17))
# (0.44, datetime.date(2018, 9, 16))
# (0.44, datetime.date(2018, 9, 15))
# (0.44, datetime.date(2018, 9, 14))
# (0.44, datetime.date(2018, 9, 13))
# (0.44, datetime.date(2018, 9, 12))
# (0.44, datetime.date(2018, 9, 11))
# (0.44, datetime.date(2018, 9, 10))
# (0.44, datetime.date(2018, 9, 9))
# (0.44, datetime.date(2018, 9, 8))
# (0.44, datetime.date(2018, 9, 7))
# (0.44, datetime.date(2018, 9, 6))
# (0.45, datetime.date(2018, 9, 5))
# (0.45, datetime.date(2018, 9, 4))
# (0.45, datetime.date(2018, 9, 3))
# (0.45, datetime.date(2018, 9, 2))
# (0.45, datetime.date(2018, 9, 1))
# (0.45, datetime.date(2018, 8, 31))
# (0.45, datetime.date(2018, 8, 30))
# (0.45, datetime.date(2018, 8, 29))
# (0.45, datetime.date(2018, 8, 28))
# (0.45, datetime.date(2018, 8, 27))
# (0.45, datetime.date(2018, 8, 26))
# (0.45, datetime.date(2018, 8, 25))
# (0.45, datetime.date(2018, 8, 24))
# (0.45, datetime.date(2018, 8, 23))
# (0.45, datetime.date(2018, 8, 22))
# (0.45, datetime.date(2018, 8, 21))
# (0.45, datetime.date(2018, 8, 20))
# (0.45, datetime.date(2018, 8, 19))
# (0.45, datetime.date(2018, 8, 18))
# (0.46, datetime.date(2018, 8, 17))
# (0.46, datetime.date(2018, 8, 16))
# (0.46, datetime.date(2018, 8, 15))
# (0.46, datetime.date(2018, 8, 14))
# (0.46, datetime.date(2018, 8, 13))
# (0.46, datetime.date(2018, 8, 12))
# (0.46, datetime.date(2018, 8, 11))
# (0.46, datetime.date(2018, 8, 10))
# (0.46, datetime.date(2018, 8, 9))
# (0.46, datetime.date(2018, 8, 8))
# (0.46, datetime.date(2018, 8, 7))
# (0.46, datetime.date(2018, 8, 6))
# (0.46, datetime.date(2018, 8, 5))
# (0.46, datetime.date(2018, 8, 4))
# (0.46, datetime.date(2018, 8, 3))
# (0.46, datetime.date(2018, 8, 2))
# (0.46, datetime.date(2018, 8, 1))
# (0.46, datetime.date(2018, 7, 31))
# (0.46, datetime.date(2018, 7, 30))
# (0.46, datetime.date(2018, 7, 29))
# (0.47, datetime.date(2018, 7, 28))
# (0.47, datetime.date(2018, 7, 27))
# (0.47, datetime.date(2018, 7, 26))
# (0.47, datetime.date(2018, 7, 25))
# (0.47, datetime.date(2018, 7, 24))
# (0.47, datetime.date(2018, 7, 23))
# (0.47, datetime.date(2018, 7, 22))
# (0.47, datetime.date(2018, 7, 21))
# (0.47, datetime.date(2018, 7, 20))
# (0.47, datetime.date(2018, 7, 19))
# (0.47, datetime.date(2018, 7, 18))
# (0.47, datetime.date(2018, 7, 17))
# (0.47, datetime.date(2018, 7, 16))
# (0.47, datetime.date(2018, 7, 15))
# (0.47, datetime.date(2018, 7, 14))
# (0.47, datetime.date(2018, 7, 13))
# (0.47, datetime.date(2018, 7, 12))
# (0.47, datetime.date(2018, 7, 11))
# (0.47, datetime.date(2018, 7, 10))
# (0.47, datetime.date(2018, 7, 9))
# (0.48, datetime.date(2018, 7, 8))
# (0.48, datetime.date(2018, 7, 7))
# (0.48, datetime.date(2018, 7, 6))
# (0.48, datetime.date(2018, 7, 5))
# (0.48, datetime.date(2018, 7, 4))
# (0.48, datetime.date(2018, 7, 3))
# (0.48, datetime.date(2018, 7, 2))
# (0.48, datetime.date(2018, 7, 1))
# (0.48, datetime.date(2018, 6, 30))
# (0.48, datetime.date(2018, 6, 29))
# (0.48, datetime.date(2018, 6, 28))
# (0.48, datetime.date(2018, 6, 27))
# (0.48, datetime.date(2018, 6, 26))
# (0.48, datetime.date(2018, 6, 25))
# (0.48, datetime.date(2018, 6, 24))
# (0.48, datetime.date(2018, 6, 23))
# (0.48, datetime.date(2018, 6, 22))
# (0.48, datetime.date(2018, 6, 21))
# (0.48, datetime.date(2018, 6, 20))
# (0.49, datetime.date(2018, 6, 19))
# (0.49, datetime.date(2018, 6, 18))
# (0.49, datetime.date(2018, 6, 17))
# (0.49, datetime.date(2018, 6, 16))
# (0.49, datetime.date(2018, 6, 15))
# (0.49, datetime.date(2018, 6, 14))
# (0.49, datetime.date(2018, 6, 13))
# (0.49, datetime.date(2018, 6, 12))
# (0.49, datetime.date(2018, 6, 11))
# (0.49, datetime.date(2018, 6, 10))
# (0.49, datetime.date(2018, 6, 9))
# (0.49, datetime.date(2018, 6, 8))
# (0.49, datetime.date(2018, 6, 7))
# (0.49, datetime.date(2018, 6, 6))
# (0.49, datetime.date(2018, 6, 5))
# (0.49, datetime.date(2018, 6, 4))
# (0.49, datetime.date(2018, 6, 3))
# (0.49, datetime.date(2018, 6, 2))
# (0.49, datetime.date(2018, 6, 1))
# (0.49, datetime.date(2018, 5, 31))
# (0.5, datetime.date(2018, 5, 30))
# (0.5, datetime.date(2018, 5, 29))
# (0.5, datetime.date(2018, 5, 28))
# (0.5, datetime.date(2018, 5, 27))
# (0.5, datetime.date(2018, 5, 26))
# (0.5, datetime.date(2018, 5, 25))
# (0.5, datetime.date(2018, 5, 24))
# (0.5, datetime.date(2018, 5, 23))
# (0.5, datetime.date(2018, 5, 22))
# (0.5, datetime.date(2018, 5, 21))
# (0.5, datetime.date(2018, 5, 20))
# (0.5, datetime.date(2018, 5, 19))
# (0.5, datetime.date(2018, 5, 18))
# (0.5, datetime.date(2018, 5, 17))
# (0.5, datetime.date(2018, 5, 16))
# (0.5, datetime.date(2018, 5, 15))
# (0.5, datetime.date(2018, 5, 14))
# (0.5, datetime.date(2018, 5, 13))
# (0.5, datetime.date(2018, 5, 12))
# (0.51, datetime.date(2018, 5, 11))
# (0.51, datetime.date(2018, 5, 10))
# (0.51, datetime.date(2018, 5, 9))
# (0.51, datetime.date(2018, 5, 8))
# (0.51, datetime.date(2018, 5, 7))
# (0.51, datetime.date(2018, 5, 6))
# (0.51, datetime.date(2018, 5, 5))
# (0.51, datetime.date(2018, 5, 4))
# (0.51, datetime.date(2018, 5, 3))
# (0.51, datetime.date(2018, 5, 2))
# (0.51, datetime.date(2018, 5, 1))
# (0.51, datetime.date(2018, 4, 30))
# (0.51, datetime.date(2018, 4, 29))
# (0.51, datetime.date(2018, 4, 28))
# (0.51, datetime.date(2018, 4, 27))
# (0.51, datetime.date(2018, 4, 26))
# (0.51, datetime.date(2018, 4, 25))
# (0.51, datetime.date(2018, 4, 24))
# (0.51, datetime.date(2018, 4, 23))
# (0.51, datetime.date(2018, 4, 22))
# (0.52, datetime.date(2018, 4, 21))
# (0.52, datetime.date(2018, 4, 20))
# (0.52, datetime.date(2018, 4, 19))
# (0.52, datetime.date(2018, 4, 18))
# (0.52, datetime.date(2018, 4, 17))
# (0.52, datetime.date(2018, 4, 16))
# (0.52, datetime.date(2018, 4, 15))
# (0.52, datetime.date(2018, 4, 14))
# (0.52, datetime.date(2018, 4, 13))
# (0.52, datetime.date(2018, 4, 12))
# (0.52, datetime.date(2018, 4, 11))
# (0.52, datetime.date(2018, 4, 10))
# (0.52, datetime.date(2018, 4, 9))
# (0.52, datetime.date(2018, 4, 8))
# (0.52, datetime.date(2018, 4, 7))
# (0.52, datetime.date(2018, 4, 6))
# (0.52, datetime.date(2018, 4, 5))
# (0.52, datetime.date(2018, 4, 4))
# (0.52, datetime.date(2018, 4, 3))
# (0.53, datetime.date(2018, 4, 2))
# (0.53, datetime.date(2018, 4, 1))
# (0.53, datetime.date(2018, 3, 31))
# (0.53, datetime.date(2018, 3, 30))
# (0.53, datetime.date(2018, 3, 29))
# (0.53, datetime.date(2018, 3, 28))
# (0.53, datetime.date(2018, 3, 27))
# (0.53, datetime.date(2018, 3, 26))
# (0.53, datetime.date(2018, 3, 25))
# (0.53, datetime.date(2018, 3, 24))
# (0.53, datetime.date(2018, 3, 23))
# (0.53, datetime.date(2018, 3, 22))
# (0.53, datetime.date(2018, 3, 21))
# (0.53, datetime.date(2018, 3, 20))
# (0.53, datetime.date(2018, 3, 19))
# (0.53, datetime.date(2018, 3, 18))
# (0.53, datetime.date(2018, 3, 17))
# (0.53, datetime.date(2018, 3, 16))
# (0.53, datetime.date(2018, 3, 15))
# (0.53, datetime.date(2018, 3, 14))
# (0.54, datetime.date(2018, 3, 13))
# (0.54, datetime.date(2018, 3, 12))
# (0.54, datetime.date(2018, 3, 11))
# (0.54, datetime.date(2018, 3, 10))
# (0.54, datetime.date(2018, 3, 9))
# (0.54, datetime.date(2018, 3, 8))
# (0.54, datetime.date(2018, 3, 7))
# (0.54, datetime.date(2018, 3, 6))
# (0.54, datetime.date(2018, 3, 5))
# (0.54, datetime.date(2018, 3, 4))
# (0.54, datetime.date(2018, 3, 3))
# (0.54, datetime.date(2018, 3, 2))
# (0.54, datetime.date(2018, 3, 1))
# (0.54, datetime.date(2018, 2, 28))
# (0.54, datetime.date(2018, 2, 27))
# (0.54, datetime.date(2018, 2, 26))
# (0.54, datetime.date(2018, 2, 25))
# (0.54, datetime.date(2018, 2, 24))
# (0.54, datetime.date(2018, 2, 23))
# (0.54, datetime.date(2018, 2, 22))
# (0.55, datetime.date(2018, 2, 21))
# (0.55, datetime.date(2018, 2, 20))
# (0.55, datetime.date(2018, 2, 19))
# (0.55, datetime.date(2018, 2, 18))
# (0.55, datetime.date(2018, 2, 17))
# (0.55, datetime.date(2018, 2, 16))
# (0.55, datetime.date(2018, 2, 15))
# (0.55, datetime.date(2018, 2, 14))
# (0.55, datetime.date(2018, 2, 13))
# (0.55, datetime.date(2018, 2, 12))
# (0.55, datetime.date(2018, 2, 11))
# (0.55, datetime.date(2018, 2, 10))
# (0.55, datetime.date(2018, 2, 9))
# (0.55, datetime.date(2018, 2, 8))
# (0.55, datetime.date(2018, 2, 7))
# (0.55, datetime.date(2018, 2, 6))
# (0.55, datetime.date(2018, 2, 5))
# (0.55, datetime.date(2018, 2, 4))
# (0.55, datetime.date(2018, 2, 3))
# (0.56, datetime.date(2018, 2, 2))
# (0.56, datetime.date(2018, 2, 1))
# (0.56, datetime.date(2018, 1, 31))
# (0.56, datetime.date(2018, 1, 30))
# (0.56, datetime.date(2018, 1, 29))
# (0.56, datetime.date(2018, 1, 28))
# (0.56, datetime.date(2018, 1, 27))
# (0.56, datetime.date(2018, 1, 26))
# (0.56, datetime.date(2018, 1, 25))
# (0.56, datetime.date(2018, 1, 24))
# (0.56, datetime.date(2018, 1, 23))
# (0.56, datetime.date(2018, 1, 22))
# (0.56, datetime.date(2018, 1, 21))
# (0.56, datetime.date(2018, 1, 20))
# (0.56, datetime.date(2018, 1, 19))
# (0.56, datetime.date(2018, 1, 18))
# (0.56, datetime.date(2018, 1, 17))
# (0.56, datetime.date(2018, 1, 16))
# (0.56, datetime.date(2018, 1, 15))
# (0.56, datetime.date(2018, 1, 14))
# (0.57, datetime.date(2018, 1, 13))
# (0.57, datetime.date(2018, 1, 12))
# (0.57, datetime.date(2018, 1, 11))
# (0.57, datetime.date(2018, 1, 10))
# (0.57, datetime.date(2018, 1, 9))
# (0.57, datetime.date(2018, 1, 8))
# (0.57, datetime.date(2018, 1, 7))
# (0.57, datetime.date(2018, 1, 6))
# (0.57, datetime.date(2018, 1, 5))
# (0.57, datetime.date(2018, 1, 4))
# (0.57, datetime.date(2018, 1, 3))
# (0.57, datetime.date(2018, 1, 2))
# (0.57, datetime.date(2018, 1, 1))
# (0.57, datetime.date(2017, 12, 31))
# (0.57, datetime.date(2017, 12, 30))
# (0.57, datetime.date(2017, 12, 29))
# (0.57, datetime.date(2017, 12, 28))
# (0.57, datetime.date(2017, 12, 27))
# (0.57, datetime.date(2017, 12, 26))
# (0.58, datetime.date(2017, 12, 25))
# (0.58, datetime.date(2017, 12, 24))
# (0.58, datetime.date(2017, 12, 23))
# (0.58, datetime.date(2017, 12, 22))
# (0.58, datetime.date(2017, 12, 21))
# (0.58, datetime.date(2017, 12, 20))
# (0.58, datetime.date(2017, 12, 19))
# (0.58, datetime.date(2017, 12, 18))
# (0.58, datetime.date(2017, 12, 17))
# (0.58, datetime.date(2017, 12, 16))
# (0.58, datetime.date(2017, 12, 15))
# (0.58, datetime.date(2017, 12, 14))
# (0.58, datetime.date(2017, 12, 13))
# (0.58, datetime.date(2017, 12, 12))
# (0.58, datetime.date(2017, 12, 11))
# (0.58, datetime.date(2017, 12, 10))
# (0.58, datetime.date(2017, 12, 9))
# (0.58, datetime.date(2017, 12, 8))
# (0.58, datetime.date(2017, 12, 7))
# (0.58, datetime.date(2017, 12, 6))
# (0.59, datetime.date(2017, 12, 5))
# (0.59, datetime.date(2017, 12, 4))
# (0.59, datetime.date(2017, 12, 3))
# (0.59, datetime.date(2017, 12, 2))
# (0.59, datetime.date(2017, 12, 1))
# (0.59, datetime.date(2017, 11, 30))
# (0.59, datetime.date(2017, 11, 29))
# (0.59, datetime.date(2017, 11, 28))
# (0.59, datetime.date(2017, 11, 27))
# (0.59, datetime.date(2017, 11, 26))
# (0.59, datetime.date(2017, 11, 25))
# (0.59, datetime.date(2017, 11, 24))
# (0.59, datetime.date(2017, 11, 23))
# (0.59, datetime.date(2017, 11, 22))
# (0.59, datetime.date(2017, 11, 21))
# (0.59, datetime.date(2017, 11, 20))
# (0.59, datetime.date(2017, 11, 19))
# (0.59, datetime.date(2017, 11, 18))
# (0.59, datetime.date(2017, 11, 17))
# (0.59, datetime.date(2017, 11, 16))
# (0.6, datetime.date(2017, 11, 15))
# (0.6, datetime.date(2017, 11, 14))
# (0.6, datetime.date(2017, 11, 13))
# (0.6, datetime.date(2017, 11, 12))
# (0.6, datetime.date(2017, 11, 11))
# (0.6, datetime.date(2017, 11, 10))
# (0.6, datetime.date(2017, 11, 9))
# (0.6, datetime.date(2017, 11, 8))
# (0.6, datetime.date(2017, 11, 7))
# (0.6, datetime.date(2017, 11, 6))
# (0.6, datetime.date(2017, 11, 5))
# (0.6, datetime.date(2017, 11, 4))
# (0.6, datetime.date(2017, 11, 3))
# (0.6, datetime.date(2017, 11, 2))
# (0.6, datetime.date(2017, 11, 1))
# (0.6, datetime.date(2017, 10, 31))
# (0.6, datetime.date(2017, 10, 30))
# (0.6, datetime.date(2017, 10, 29))
# (0.6, datetime.date(2017, 10, 28))
# (0.61, datetime.date(2017, 10, 27))
# (0.61, datetime.date(2017, 10, 26))
# (0.61, datetime.date(2017, 10, 25))
# (0.61, datetime.date(2017, 10, 24))
# (0.61, datetime.date(2017, 10, 23))
# (0.61, datetime.date(2017, 10, 22))
# (0.61, datetime.date(2017, 10, 21))
# (0.61, datetime.date(2017, 10, 20))
# (0.61, datetime.date(2017, 10, 19))
# (0.61, datetime.date(2017, 10, 18))
# (0.61, datetime.date(2017, 10, 17))
# (0.61, datetime.date(2017, 10, 16))
# (0.61, datetime.date(2017, 10, 15))
# (0.61, datetime.date(2017, 10, 14))
# (0.61, datetime.date(2017, 10, 13))
# (0.61, datetime.date(2017, 10, 12))
# (0.61, datetime.date(2017, 10, 11))
# (0.61, datetime.date(2017, 10, 10))
# (0.61, datetime.date(2017, 10, 9))
# (0.61, datetime.date(2017, 10, 8))
# (0.62, datetime.date(2017, 10, 7))
# (0.62, datetime.date(2017, 10, 6))
# (0.62, datetime.date(2017, 10, 5))
# (0.62, datetime.date(2017, 10, 4))
# (0.62, datetime.date(2017, 10, 3))
# (0.62, datetime.date(2017, 10, 2))
# (0.62, datetime.date(2017, 10, 1))
# (0.62, datetime.date(2017, 9, 30))
# (0.62, datetime.date(2017, 9, 29))
# (0.62, datetime.date(2017, 9, 28))
# (0.62, datetime.date(2017, 9, 27))
# (0.62, datetime.date(2017, 9, 26))
# (0.62, datetime.date(2017, 9, 25))
# (0.62, datetime.date(2017, 9, 24))
# (0.62, datetime.date(2017, 9, 23))
# (0.62, datetime.date(2017, 9, 22))
# (0.62, datetime.date(2017, 9, 21))
# (0.62, datetime.date(2017, 9, 20))
# (0.62, datetime.date(2017, 9, 19))
# (0.63, datetime.date(2017, 9, 18))
# (0.63, datetime.date(2017, 9, 17))
# (0.63, datetime.date(2017, 9, 16))
# (0.63, datetime.date(2017, 9, 15))
# (0.63, datetime.date(2017, 9, 14))
# (0.63, datetime.date(2017, 9, 13))
# (0.63, datetime.date(2017, 9, 12))
# (0.63, datetime.date(2017, 9, 11))
# (0.63, datetime.date(2017, 9, 10))
# (0.63, datetime.date(2017, 9, 9))
# (0.63, datetime.date(2017, 9, 8))
# (0.63, datetime.date(2017, 9, 7))
# (0.63, datetime.date(2017, 9, 6))
# (0.63, datetime.date(2017, 9, 5))
# (0.63, datetime.date(2017, 9, 4))
# (0.63, datetime.date(2017, 9, 3))
# (0.63, datetime.date(2017, 9, 2))
# (0.63, datetime.date(2017, 9, 1))
# (0.63, datetime.date(2017, 8, 31))
# (0.63, datetime.date(2017, 8, 30))
# (0.64, datetime.date(2017, 8, 29))
# (0.64, datetime.date(2017, 8, 28))
# (0.64, datetime.date(2017, 8, 27))
# (0.64, datetime.date(2017, 8, 26))
# (0.64, datetime.date(2017, 8, 25))
# (0.64, datetime.date(2017, 8, 24))
# (0.64, datetime.date(2017, 8, 23))
# (0.64, datetime.date(2017, 8, 22))
# (0.64, datetime.date(2017, 8, 21))
# (0.64, datetime.date(2017, 8, 20))
# (0.64, datetime.date(2017, 8, 19))
# (0.64, datetime.date(2017, 8, 18))
# (0.64, datetime.date(2017, 8, 17))
# (0.64, datetime.date(2017, 8, 16))
# (0.64, datetime.date(2017, 8, 15))
# (0.64, datetime.date(2017, 8, 14))
# (0.64, datetime.date(2017, 8, 13))
# (0.64, datetime.date(2017, 8, 12))
# (0.64, datetime.date(2017, 8, 11))
# (0.65, datetime.date(2017, 8, 10))
# (0.65, datetime.date(2017, 8, 9))
# (0.65, datetime.date(2017, 8, 8))
# (0.65, datetime.date(2017, 8, 7))
# (0.65, datetime.date(2017, 8, 6))
# (0.65, datetime.date(2017, 8, 5))
# (0.65, datetime.date(2017, 8, 4))
# (0.65, datetime.date(2017, 8, 3))
# (0.65, datetime.date(2017, 8, 2))
# (0.65, datetime.date(2017, 8, 1))
# (0.65, datetime.date(2017, 7, 31))
# (0.65, datetime.date(2017, 7, 30))
# (0.65, datetime.date(2017, 7, 29))
# (0.65, datetime.date(2017, 7, 28))
# (0.65, datetime.date(2017, 7, 27))
# (0.65, datetime.date(2017, 7, 26))
# (0.65, datetime.date(2017, 7, 25))
# (0.65, datetime.date(2017, 7, 24))
# (0.65, datetime.date(2017, 7, 23))
# (0.65, datetime.date(2017, 7, 22))
# (0.66, datetime.date(2017, 7, 21))
# (0.66, datetime.date(2017, 7, 20))
# (0.66, datetime.date(2017, 7, 19))
# (0.66, datetime.date(2017, 7, 18))
# (0.66, datetime.date(2017, 7, 17))
# (0.66, datetime.date(2017, 7, 16))
# (0.66, datetime.date(2017, 7, 15))
# (0.66, datetime.date(2017, 7, 14))
# (0.66, datetime.date(2017, 7, 13))
# (0.66, datetime.date(2017, 7, 12))
# (0.66, datetime.date(2017, 7, 11))
# (0.66, datetime.date(2017, 7, 10))
# (0.66, datetime.date(2017, 7, 9))
# (0.66, datetime.date(2017, 7, 8))
# (0.66, datetime.date(2017, 7, 7))
# (0.66, datetime.date(2017, 7, 6))
# (0.66, datetime.date(2017, 7, 5))
# (0.66, datetime.date(2017, 7, 4))
# (0.66, datetime.date(2017, 7, 3))
# (0.66, datetime.date(2017, 7, 2))
# (0.67, datetime.date(2017, 7, 1))
# (0.67, datetime.date(2017, 6, 30))
# (0.67, datetime.date(2017, 6, 29))
# (0.67, datetime.date(2017, 6, 28))
# (0.67, datetime.date(2017, 6, 27))
# (0.67, datetime.date(2017, 6, 26))
# (0.67, datetime.date(2017, 6, 25))
# (0.67, datetime.date(2017, 6, 24))
# (0.67, datetime.date(2017, 6, 23))
# (0.67, datetime.date(2017, 6, 22))
# (0.67, datetime.date(2017, 6, 21))
# (0.67, datetime.date(2017, 6, 20))
# (0.67, datetime.date(2017, 6, 19))
# (0.67, datetime.date(2017, 6, 18))
# (0.67, datetime.date(2017, 6, 17))
# (0.67, datetime.date(2017, 6, 16))
# (0.67, datetime.date(2017, 6, 15))
# (0.67, datetime.date(2017, 6, 14))
# (0.67, datetime.date(2017, 6, 13))
# (0.68, datetime.date(2017, 6, 12))
# (0.68, datetime.date(2017, 6, 11))
# (0.68, datetime.date(2017, 6, 10))
# (0.68, datetime.date(2017, 6, 9))
# (0.68, datetime.date(2017, 6, 8))
# (0.68, datetime.date(2017, 6, 7))
# (0.68, datetime.date(2017, 6, 6))
# (0.68, datetime.date(2017, 6, 5))
# (0.68, datetime.date(2017, 6, 4))
# (0.68, datetime.date(2017, 6, 3))
# (0.68, datetime.date(2017, 6, 2))
# (0.68, datetime.date(2017, 6, 1))
# (0.68, datetime.date(2017, 5, 31))
# (0.68, datetime.date(2017, 5, 30))
# (0.68, datetime.date(2017, 5, 29))
# (0.68, datetime.date(2017, 5, 28))
# (0.68, datetime.date(2017, 5, 27))
# (0.68, datetime.date(2017, 5, 26))
# (0.68, datetime.date(2017, 5, 25))
# (0.68, datetime.date(2017, 5, 24))
# (0.69, datetime.date(2017, 5, 23))
# (0.69, datetime.date(2017, 5, 22))
# (0.69, datetime.date(2017, 5, 21))
# (0.69, datetime.date(2017, 5, 20))
# (0.69, datetime.date(2017, 5, 19))
# (0.69, datetime.date(2017, 5, 18))
# (0.69, datetime.date(2017, 5, 17))
# (0.69, datetime.date(2017, 5, 16))
# (0.69, datetime.date(2017, 5, 15))
# (0.69, datetime.date(2017, 5, 14))
# (0.69, datetime.date(2017, 5, 13))
# (0.69, datetime.date(2017, 5, 12))
# (0.69, datetime.date(2017, 5, 11))
# (0.69, datetime.date(2017, 5, 10))
# (0.69, datetime.date(2017, 5, 9))
# (0.69, datetime.date(2017, 5, 8))
# (0.69, datetime.date(2017, 5, 7))
# (0.69, datetime.date(2017, 5, 6))
# (0.69, datetime.date(2017, 5, 5))
# (0.7, datetime.date(2017, 5, 4))
# (0.7, datetime.date(2017, 5, 3))
# (0.7, datetime.date(2017, 5, 2))
# (0.7, datetime.date(2017, 5, 1))
# (0.7, datetime.date(2017, 4, 30))
# (0.7, datetime.date(2017, 4, 29))
# (0.7, datetime.date(2017, 4, 28))
# (0.7, datetime.date(2017, 4, 27))
# (0.7, datetime.date(2017, 4, 26))
# (0.7, datetime.date(2017, 4, 25))
# (0.7, datetime.date(2017, 4, 24))
# (0.7, datetime.date(2017, 4, 23))
# (0.7, datetime.date(2017, 4, 22))
# (0.7, datetime.date(2017, 4, 21))
# (0.7, datetime.date(2017, 4, 20))
# ...
# (0.77, datetime.date(2016, 12, 15))
# (0.77, datetime.date(2016, 12, 14))
# (0.77, datetime.date(2016, 12, 13))
# (0.77, datetime.date(2016, 12, 12))
# (0.77, datetime.date(2016, 12, 11))
# (0.77, datetime.date(2016, 12, 10))
# (0.77, datetime.date(2016, 12, 9))
# (0.77, datetime.date(2016, 12, 8))
# (0.77, datetime.date(2016, 12, 7))
# (0.77, datetime.date(2016, 12, 6))
# (0.77, datetime.date(2016, 12, 5))
# (0.77, datetime.date(2016, 12, 4))
# (0.77, datetime.date(2016, 12, 3))
# (0.77, datetime.date(2016, 12, 2))
# (0.77, datetime.date(2016, 12, 1))
# (0.77, datetime.date(2016, 11, 30))
# (0.77, datetime.date(2016, 11, 29))
# (0.78, datetime.date(2016, 11, 28))
# (0.78, datetime.date(2016, 11, 27))
# (0.78, datetime.date(2016, 11, 26))
# (0.78, datetime.date(2016, 11, 25))
# (0.78, datetime.date(2016, 11, 24))
# (0.78, datetime.date(2016, 11, 23))
# (0.78, datetime.date(2016, 11, 22))
# (0.78, datetime.date(2016, 11, 21))
# (0.78, datetime.date(2016, 11, 20))
# (0.78, datetime.date(2016, 11, 19))
# (0.78, datetime.date(2016, 11, 18))
# (0.78, datetime.date(2016, 11, 17))
# (0.78, datetime.date(2016, 11, 16))
# (0.78, datetime.date(2016, 11, 15))
# (0.78, datetime.date(2016, 11, 14))
# (0.78, datetime.date(2016, 11, 13))
# (0.78, datetime.date(2016, 11, 12))
# (0.78, datetime.date(2016, 11, 11))
# (0.78, datetime.date(2016, 11, 10))
# (0.78, datetime.date(2016, 11, 9))
# (0.79, datetime.date(2016, 11, 8))
# (0.79, datetime.date(2016, 11, 7))
# (0.79, datetime.date(2016, 11, 6))
# (0.79, datetime.date(2016, 11, 5))
# (0.79, datetime.date(2016, 11, 4))
# (0.79, datetime.date(2016, 11, 3))
# (0.79, datetime.date(2016, 11, 2))
# (0.79, datetime.date(2016, 11, 1))
# (0.79, datetime.date(2016, 10, 31))
# (0.79, datetime.date(2016, 10, 30))
# (0.79, datetime.date(2016, 10, 29))
# (0.79, datetime.date(2016, 10, 28))
# (0.79, datetime.date(2016, 10, 27))
# (0.79, datetime.date(2016, 10, 26))
# (0.79, datetime.date(2016, 10, 25))
# (0.79, datetime.date(2016, 10, 24))
# (0.79, datetime.date(2016, 10, 23))
# (0.79, datetime.date(2016, 10, 22))
# (0.79, datetime.date(2016, 10, 21))
# (0.8, datetime.date(2016, 10, 20))
# (0.8, datetime.date(2016, 10, 19))
# (0.8, datetime.date(2016, 10, 18))
# (0.8, datetime.date(2016, 10, 17))
# (0.8, datetime.date(2016, 10, 16))
# (0.8, datetime.date(2016, 10, 15))
# (0.8, datetime.date(2016, 10, 14))
# (0.8, datetime.date(2016, 10, 13))
# (0.8, datetime.date(2016, 10, 12))
# (0.8, datetime.date(2016, 10, 11))
# (0.8, datetime.date(2016, 10, 10))
# (0.8, datetime.date(2016, 10, 9))
# (0.8, datetime.date(2016, 10, 8))
# (0.8, datetime.date(2016, 10, 7))
# (0.8, datetime.date(2016, 10, 6))
# (0.8, datetime.date(2016, 10, 5))
# (0.8, datetime.date(2016, 10, 4))
# (0.8, datetime.date(2016, 10, 3))
# (0.8, datetime.date(2016, 10, 2))
# (0.8, datetime.date(2016, 10, 1))
# (0.81, datetime.date(2016, 9, 30))
# (0.81, datetime.date(2016, 9, 29))
# (0.81, datetime.date(2016, 9, 28))
# (0.81, datetime.date(2016, 9, 27))
# (0.81, datetime.date(2016, 9, 26))
# (0.81, datetime.date(2016, 9, 25))
# (0.81, datetime.date(2016, 9, 24))
# (0.81, datetime.date(2016, 9, 23))
# (0.81, datetime.date(2016, 9, 22))
# (0.81, datetime.date(2016, 9, 21))
# (0.81, datetime.date(2016, 9, 20))
# (0.81, datetime.date(2016, 9, 19))
# (0.81, datetime.date(2016, 9, 18))
# (0.81, datetime.date(2016, 9, 17))
# (0.81, datetime.date(2016, 9, 16))
# (0.81, datetime.date(2016, 9, 15))
# (0.81, datetime.date(2016, 9, 14))
# (0.81, datetime.date(2016, 9, 13))
# (0.81, datetime.date(2016, 9, 12))
# (0.82, datetime.date(2016, 9, 11))
# (0.82, datetime.date(2016, 9, 10))
# (0.82, datetime.date(2016, 9, 9))
# (0.82, datetime.date(2016, 9, 8))
# (0.82, datetime.date(2016, 9, 7))
# (0.82, datetime.date(2016, 9, 6))
# (0.82, datetime.date(2016, 9, 5))
# (0.82, datetime.date(2016, 9, 4))
# (0.82, datetime.date(2016, 9, 3))
# (0.82, datetime.date(2016, 9, 2))
# (0.82, datetime.date(2016, 9, 1))
# (0.82, datetime.date(2016, 8, 31))
# (0.82, datetime.date(2016, 8, 30))
# (0.82, datetime.date(2016, 8, 29))
# (0.82, datetime.date(2016, 8, 28))
# (0.82, datetime.date(2016, 8, 27))
# (0.82, datetime.date(2016, 8, 26))
# (0.82, datetime.date(2016, 8, 25))
# (0.82, datetime.date(2016, 8, 24))
# (0.82, datetime.date(2016, 8, 23))
# (0.83, datetime.date(2016, 8, 22))
# (0.83, datetime.date(2016, 8, 21))
# (0.83, datetime.date(2016, 8, 20))
# (0.83, datetime.date(2016, 8, 19))
# (0.83, datetime.date(2016, 8, 18))
# (0.83, datetime.date(2016, 8, 17))
# (0.83, datetime.date(2016, 8, 16))
# (0.83, datetime.date(2016, 8, 15))
# (0.83, datetime.date(2016, 8, 14))
# (0.83, datetime.date(2016, 8, 13))
# (0.83, datetime.date(2016, 8, 12))
# (0.83, datetime.date(2016, 8, 11))
# (0.83, datetime.date(2016, 8, 10))
# (0.83, datetime.date(2016, 8, 9))
# (0.83, datetime.date(2016, 8, 8))
# (0.83, datetime.date(2016, 8, 7))
# (0.83, datetime.date(2016, 8, 6))
# (0.83, datetime.date(2016, 8, 5))
# (0.83, datetime.date(2016, 8, 4))
# (0.84, datetime.date(2016, 8, 3))
# (0.84, datetime.date(2016, 8, 2))
# (0.84, datetime.date(2016, 8, 1))
# (0.84, datetime.date(2016, 7, 31))
# (0.84, datetime.date(2016, 7, 30))
# (0.84, datetime.date(2016, 7, 29))
# (0.84, datetime.date(2016, 7, 28))
# (0.84, datetime.date(2016, 7, 27))
# (0.84, datetime.date(2016, 7, 26))
# (0.84, datetime.date(2016, 7, 25))
# (0.84, datetime.date(2016, 7, 24))
# (0.84, datetime.date(2016, 7, 23))
# (0.84, datetime.date(2016, 7, 22))
# (0.84, datetime.date(2016, 7, 21))
# (0.84, datetime.date(2016, 7, 20))
# (0.84, datetime.date(2016, 7, 19))
# (0.84, datetime.date(2016, 7, 18))
# (0.84, datetime.date(2016, 7, 17))
# (0.84, datetime.date(2016, 7, 16))
# (0.84, datetime.date(2016, 7, 15))
# (0.85, datetime.date(2016, 7, 14))
# (0.85, datetime.date(2016, 7, 13))
# (0.85, datetime.date(2016, 7, 12))
# (0.85, datetime.date(2016, 7, 11))
# (0.85, datetime.date(2016, 7, 10))
# (0.85, datetime.date(2016, 7, 9))
# (0.85, datetime.date(2016, 7, 8))
# (0.85, datetime.date(2016, 7, 7))
# (0.85, datetime.date(2016, 7, 6))
# (0.85, datetime.date(2016, 7, 5))
# (0.85, datetime.date(2016, 7, 4))
# (0.85, datetime.date(2016, 7, 3))
# (0.85, datetime.date(2016, 7, 2))
# (0.85, datetime.date(2016, 7, 1))
# (0.85, datetime.date(2016, 6, 30))
# (0.85, datetime.date(2016, 6, 29))
# (0.85, datetime.date(2016, 6, 28))
# (0.85, datetime.date(2016, 6, 27))
# (0.85, datetime.date(2016, 6, 26))
# (0.85, datetime.date(2016, 6, 25))
# (0.86, datetime.date(2016, 6, 24))
# (0.86, datetime.date(2016, 6, 23))
# (0.86, datetime.date(2016, 6, 22))
# (0.86, datetime.date(2016, 6, 21))
# (0.86, datetime.date(2016, 6, 20))
# (0.86, datetime.date(2016, 6, 19))
# (0.86, datetime.date(2016, 6, 18))
# (0.86, datetime.date(2016, 6, 17))
# (0.86, datetime.date(2016, 6, 16))
# (0.86, datetime.date(2016, 6, 15))
# (0.86, datetime.date(2016, 6, 14))
# (0.86, datetime.date(2016, 6, 13))
# (0.86, datetime.date(2016, 6, 12))
# (0.86, datetime.date(2016, 6, 11))
# (0.86, datetime.date(2016, 6, 10))
# (0.86, datetime.date(2016, 6, 9))
# (0.86, datetime.date(2016, 6, 8))
# (0.86, datetime.date(2016, 6, 7))
# (0.86, datetime.date(2016, 6, 6))
# (0.87, datetime.date(2016, 6, 5))
# (0.87, datetime.date(2016, 6, 4))
# (0.87, datetime.date(2016, 6, 3))
# (0.87, datetime.date(2016, 6, 2))
# (0.87, datetime.date(2016, 6, 1))
# (0.87, datetime.date(2016, 5, 31))
# (0.87, datetime.date(2016, 5, 30))
# (0.87, datetime.date(2016, 5, 29))
# (0.87, datetime.date(2016, 5, 28))
# (0.87, datetime.date(2016, 5, 27))
# (0.87, datetime.date(2016, 5, 26))
# (0.87, datetime.date(2016, 5, 25))
# (0.87, datetime.date(2016, 5, 24))
# (0.87, datetime.date(2016, 5, 23))
# (0.87, datetime.date(2016, 5, 22))
# (0.87, datetime.date(2016, 5, 21))
# (0.87, datetime.date(2016, 5, 20))
# (0.87, datetime.date(2016, 5, 19))
# (0.87, datetime.date(2016, 5, 18))
# (0.87, datetime.date(2016, 5, 17))
# (0.88, datetime.date(2016, 5, 16))
# (0.88, datetime.date(2016, 5, 15))
# (0.88, datetime.date(2016, 5, 14))
# (0.88, datetime.date(2016, 5, 13))
# (0.88, datetime.date(2016, 5, 12))
# (0.88, datetime.date(2016, 5, 11))
# (0.88, datetime.date(2016, 5, 10))
# (0.88, datetime.date(2016, 5, 9))
# (0.88, datetime.date(2016, 5, 8))
# (0.88, datetime.date(2016, 5, 7))
# (0.88, datetime.date(2016, 5, 6))
# (0.88, datetime.date(2016, 5, 5))
# (0.88, datetime.date(2016, 5, 4))
# (0.88, datetime.date(2016, 5, 3))
# (0.88, datetime.date(2016, 5, 2))
# (0.88, datetime.date(2016, 5, 1))
# (0.88, datetime.date(2016, 4, 30))
# (0.88, datetime.date(2016, 4, 29))
# (0.88, datetime.date(2016, 4, 28))
# (0.89, datetime.date(2016, 4, 27))
# (0.89, datetime.date(2016, 4, 26))
# (0.89, datetime.date(2016, 4, 25))
# (0.89, datetime.date(2016, 4, 24))
# (0.89, datetime.date(2016, 4, 23))
# (0.89, datetime.date(2016, 4, 22))
# (0.89, datetime.date(2016, 4, 21))
# (0.89, datetime.date(2016, 4, 20))
# (0.89, datetime.date(2016, 4, 19))
# (0.89, datetime.date(2016, 4, 18))
# (0.89, datetime.date(2016, 4, 17))
# (0.89, datetime.date(2016, 4, 16))
# (0.89, datetime.date(2016, 4, 15))
# (0.89, datetime.date(2016, 4, 14))
# (0.89, datetime.date(2016, 4, 13))
# (0.89, datetime.date(2016, 4, 12))
# (0.89, datetime.date(2016, 4, 11))
# (0.89, datetime.date(2016, 4, 10))
# (0.89, datetime.date(2016, 4, 9))
# (0.89, datetime.date(2016, 4, 8))
# (0.9, datetime.date(2016, 4, 7))
# (0.9, datetime.date(2016, 4, 6))
# (0.9, datetime.date(2016, 4, 5))
# (0.9, datetime.date(2016, 4, 4))
# (0.9, datetime.date(2016, 4, 3))
# (0.9, datetime.date(2016, 4, 2))
# (0.9, datetime.date(2016, 4, 1))
# (0.9, datetime.date(2016, 3, 31))
# (0.9, datetime.date(2016, 3, 30))
# (0.9, datetime.date(2016, 3, 29))
# (0.9, datetime.date(2016, 3, 28))
# (0.9, datetime.date(2016, 3, 27))
# (0.9, datetime.date(2016, 3, 26))
# (0.9, datetime.date(2016, 3, 25))
# (0.9, datetime.date(2016, 3, 24))
# (0.9, datetime.date(2016, 3, 23))
# (0.9, datetime.date(2016, 3, 22))
# (0.9, datetime.date(2016, 3, 21))
# (0.9, datetime.date(2016, 3, 20))
# (0.91, datetime.date(2016, 3, 19))
# (0.91, datetime.date(2016, 3, 18))
# (0.91, datetime.date(2016, 3, 17))
# (0.91, datetime.date(2016, 3, 16))
# (0.91, datetime.date(2016, 3, 15))
# (0.91, datetime.date(2016, 3, 14))
# (0.91, datetime.date(2016, 3, 13))
# (0.91, datetime.date(2016, 3, 12))
# (0.91, datetime.date(2016, 3, 11))
# (0.91, datetime.date(2016, 3, 10))
# (0.91, datetime.date(2016, 3, 9))
# (0.91, datetime.date(2016, 3, 8))
# (0.91, datetime.date(2016, 3, 7))
# (0.91, datetime.date(2016, 3, 6))
# (0.91, datetime.date(2016, 3, 5))
# (0.91, datetime.date(2016, 3, 4))
# (0.91, datetime.date(2016, 3, 3))
# (0.91, datetime.date(2016, 3, 2))
# (0.91, datetime.date(2016, 3, 1))
# (0.91, datetime.date(2016, 2, 29))
# (0.92, datetime.date(2016, 2, 28))
# (0.92, datetime.date(2016, 2, 27))
# (0.92, datetime.date(2016, 2, 26))
# (0.92, datetime.date(2016, 2, 25))
# (0.92, datetime.date(2016, 2, 24))
# (0.92, datetime.date(2016, 2, 23))
# (0.92, datetime.date(2016, 2, 22))
# (0.92, datetime.date(2016, 2, 21))
# (0.92, datetime.date(2016, 2, 20))
# (0.92, datetime.date(2016, 2, 19))
# (0.92, datetime.date(2016, 2, 18))
# (0.92, datetime.date(2016, 2, 17))
# (0.92, datetime.date(2016, 2, 16))
# (0.92, datetime.date(2016, 2, 15))
# (0.92, datetime.date(2016, 2, 14))
# (0.92, datetime.date(2016, 2, 13))
# (0.92, datetime.date(2016, 2, 12))
# (0.92, datetime.date(2016, 2, 11))
# (0.92, datetime.date(2016, 2, 10))
# (0.92, datetime.date(2016, 2, 9))
# (0.93, datetime.date(2016, 2, 8))
# (0.93, datetime.date(2016, 2, 7))
# (0.93, datetime.date(2016, 2, 6))
# (0.93, datetime.date(2016, 2, 5))
# (0.93, datetime.date(2016, 2, 4))
# (0.93, datetime.date(2016, 2, 3))
# (0.93, datetime.date(2016, 2, 2))
# (0.93, datetime.date(2016, 2, 1))
# (0.93, datetime.date(2016, 1, 31))
# (0.93, datetime.date(2016, 1, 30))
# (0.93, datetime.date(2016, 1, 29))
# (0.93, datetime.date(2016, 1, 28))
# (0.93, datetime.date(2016, 1, 27))
# (0.93, datetime.date(2016, 1, 26))
# (0.93, datetime.date(2016, 1, 25))
# (0.93, datetime.date(2016, 1, 24))
# (0.93, datetime.date(2016, 1, 23))
# (0.93, datetime.date(2016, 1, 22))
# (0.93, datetime.date(2016, 1, 21))
# (0.94, datetime.date(2016, 1, 20))
# (0.94, datetime.date(2016, 1, 19))
# (0.94, datetime.date(2016, 1, 18))
# (0.94, datetime.date(2016, 1, 17))
# (0.94, datetime.date(2016, 1, 16))
# (0.94, datetime.date(2016, 1, 15))
# (0.94, datetime.date(2016, 1, 14))
# (0.94, datetime.date(2016, 1, 13))
# (0.94, datetime.date(2016, 1, 12))
# (0.94, datetime.date(2016, 1, 11))
# (0.94, datetime.date(2016, 1, 10))
# (0.94, datetime.date(2016, 1, 9))
# (0.94, datetime.date(2016, 1, 8))
# (0.94, datetime.date(2016, 1, 7))
# (0.94, datetime.date(2016, 1, 6))
# (0.94, datetime.date(2016, 1, 5))
# (0.94, datetime.date(2016, 1, 4))
# (0.94, datetime.date(2016, 1, 3))
# (0.94, datetime.date(2016, 1, 2))
# (0.94, datetime.date(2016, 1, 1))
# (0.95, datetime.date(2015, 12, 31))
# (0.95, datetime.date(2015, 12, 30))
# (0.95, datetime.date(2015, 12, 29))
# (0.95, datetime.date(2015, 12, 28))
# (0.95, datetime.date(2015, 12, 27))
# (0.95, datetime.date(2015, 12, 26))
# (0.95, datetime.date(2015, 12, 25))
# (0.95, datetime.date(2015, 12, 24))
# (0.95, datetime.date(2015, 12, 23))
# (0.95, datetime.date(2015, 12, 22))
# (0.95, datetime.date(2015, 12, 21))
# (0.95, datetime.date(2015, 12, 20))
# (0.95, datetime.date(2015, 12, 19))
# (0.95, datetime.date(2015, 12, 18))
# (0.95, datetime.date(2015, 12, 17))
# (0.95, datetime.date(2015, 12, 16))
# (0.95, datetime.date(2015, 12, 15))
# (0.95, datetime.date(2015, 12, 14))
# (0.95, datetime.date(2015, 12, 13))
# (0.96, datetime.date(2015, 12, 12))
# (0.96, datetime.date(2015, 12, 11))
# (0.96, datetime.date(2015, 12, 10))
# (0.96, datetime.date(2015, 12, 9))
# (0.96, datetime.date(2015, 12, 8))
# (0.96, datetime.date(2015, 12, 7))
# (0.96, datetime.date(2015, 12, 6))
# (0.96, datetime.date(2015, 12, 5))
# (0.96, datetime.date(2015, 12, 4))
# (0.96, datetime.date(2015, 12, 3))
# (0.96, datetime.date(2015, 12, 2))
# (0.96, datetime.date(2015, 12, 1))
# (0.96, datetime.date(2015, 11, 30))
# (0.96, datetime.date(2015, 11, 29))
# (0.96, datetime.date(2015, 11, 28))
# (0.96, datetime.date(2015, 11, 27))
# (0.96, datetime.date(2015, 11, 26))
# (0.96, datetime.date(2015, 11, 25))
# (0.96, datetime.date(2015, 11, 24))
# (0.96, datetime.date(2015, 11, 23))
# (0.97, datetime.date(2015, 11, 22))
# (0.97, datetime.date(2015, 11, 21))
# (0.97, datetime.date(2015, 11, 20))
# (0.97, datetime.date(2015, 11, 19))
# (0.97, datetime.date(2015, 11, 18))
# (0.97, datetime.date(2015, 11, 17))
# (0.97, datetime.date(2015, 11, 16))
# (0.97, datetime.date(2015, 11, 15))
# (0.97, datetime.date(2015, 11, 14))
# (0.97, datetime.date(2015, 11, 13))
# (0.97, datetime.date(2015, 11, 12))
# (0.97, datetime.date(2015, 11, 11))
# (0.97, datetime.date(2015, 11, 10))
# (0.97, datetime.date(2015, 11, 9))
# (0.97, datetime.date(2015, 11, 8))
# (0.97, datetime.date(2015, 11, 7))
# (0.97, datetime.date(2015, 11, 6))
# (0.97, datetime.date(2015, 11, 5))
# (0.97, datetime.date(2015, 11, 4))
# (0.97, datetime.date(2015, 11, 3))
# (0.98, datetime.date(2015, 11, 2))
# (0.98, datetime.date(2015, 11, 1))
# (0.98, datetime.date(2015, 10, 31))
# (0.98, datetime.date(2015, 10, 30))
# (0.98, datetime.date(2015, 10, 29))
# (0.98, datetime.date(2015, 10, 28))
# (0.98, datetime.date(2015, 10, 27))
# (0.98, datetime.date(2015, 10, 26))
# (0.98, datetime.date(2015, 10, 25))
# (0.98, datetime.date(2015, 10, 24))
# (0.98, datetime.date(2015, 10, 23))
# (0.98, datetime.date(2015, 10, 22))
# (0.98, datetime.date(2015, 10, 21))
# (0.98, datetime.date(2015, 10, 20))
# (0.98, datetime.date(2015, 10, 19))
# (0.98, datetime.date(2015, 10, 18))
# (0.98, datetime.date(2015, 10, 17))
# (0.98, datetime.date(2015, 10, 16))
# (0.98, datetime.date(2015, 10, 15))
# (0.99, datetime.date(2015, 10, 14))
# (0.99, datetime.date(2015, 10, 13))
# (0.99, datetime.date(2015, 10, 12))
# (0.99, datetime.date(2015, 10, 11))
# (0.99, datetime.date(2015, 10, 10))
# (0.99, datetime.date(2015, 10, 9))
# (0.99, datetime.date(2015, 10, 8))
# (0.99, datetime.date(2015, 10, 7))
# (0.99, datetime.date(2015, 10, 6))
# (0.99, datetime.date(2015, 10, 5))
# (0.99, datetime.date(2015, 10, 4))
# (0.99, datetime.date(2015, 10, 3))
# (0.99, datetime.date(2015, 10, 2))
# (0.99, datetime.date(2015, 10, 1))
# (0.99, datetime.date(2015, 9, 30))
# (0.99, datetime.date(2015, 9, 29))
# (0.99, datetime.date(2015, 9, 28))
# (0.99, datetime.date(2015, 9, 27))
# (0.99, datetime.date(2015, 9, 26))
# (0.99, datetime.date(2015, 9, 25))
# (1.0, datetime.date(2015, 9, 24))
# (1.0, datetime.date(2015, 9, 23))
# (1.0, datetime.date(2015, 9, 22))
# (1.0, datetime.date(2015, 9, 21))
# (1.0, datetime.date(2015, 9, 20))
# (1.0, datetime.date(2015, 9, 19))
# (1.0, datetime.date(2015, 9, 18))
# (1.0, datetime.date(2015, 9, 17))
# (1.0, datetime.date(2015, 9, 16))

# %%
# save daily dairy data in raw json format

# add the date to each entry
[daily_diary[i].update({'date':dates[i].strftime('%Y-%m-%d')}) for i in range(len(dates))]
with open(food_diary_json_file, 'w', encoding='utf-8') as f:
    json.dump(daily_diary, f, ensure_ascii=False, indent=4)

# %%
# save daily totals

daily_totals_df = pd.DataFrame(daily_totals)
daily_totals_df['date'] = dates
daily_totals_df.sort_values('date', inplace=True)
daily_totals_df.reset_index(inplace=True, drop=True)
daily_totals_df = daily_totals_df[['date', 'calories', 'carbohydrates', 'fat', 'protein', 'sodium', 'sugar']]
daily_totals_df.to_csv(food_tot_file, index=False)

# %%
# save daily meal totals

def add_date_meal(x, d):
    x[0]['date']=d
    x[0]['meal']='breakfast'
    x[0]['meal_ind']=0
    x[1]['date']=d
    x[1]['meal']='lunch'
    x[1]['meal_ind']=1
    x[2]['date']=d
    x[2]['meal']='dinner'
    x[2]['meal_ind']=2
    x[3]['date']=d
    x[3]['meal']='snack'
    x[3]['meal_ind']=3
    return x

daily_meal_totals_df = [add_date_meal(daily_meal_totals[i], dates[i]) for i in range(len(dates))]
daily_meal_totals_df = [item for sublist in daily_meal_totals_df for item in sublist]
daily_meal_totals_df = pd.DataFrame(daily_meal_totals_df).fillna(0)
daily_meal_totals_df.sort_values(['date', 'meal_ind'], inplace=True)
daily_meal_totals_df.reset_index(inplace=True, drop=True)
daily_meal_totals_df = daily_meal_totals_df[['date', 'meal', 'calories', 'carbohydrates', 'fat', 'protein', 'sodium', 'sugar']]
daily_meal_totals_df.to_csv(food_meals_tot_file, index=False)

# %%
# save daily diary entries

# first, open daily diary json file
with open(food_diary_json_file) as data_file:
    daily_diary_saved = json.load(data_file)

def add_date_meal_to_diary(day_dict):
    day_date = day_dict['date']
    diary = day_dict['breakfast']
    [x.update({'date':day_date, 'meal':'breakfast', 'meal_ind':0}) for x in diary]
    [x.update(x['nutrition_information']) for x in diary]
    [x.pop('nutrition_information', None) for x in diary]
    diary = day_dict['lunch']
    [x.update({'date':day_date, 'meal':'lunch', 'meal_ind':1}) for x in diary]
    [x.update(x['nutrition_information']) for x in diary]
    [x.pop('nutrition_information', None) for x in diary]
    diary = day_dict['dinner']
    [x.update({'date':day_date, 'meal':'dinner', 'meal_ind':2}) for x in diary]
    [x.update(x['nutrition_information']) for x in diary]
    [x.pop('nutrition_information', None) for x in diary]
    diary = day_dict['snacks']
    [x.update({'date':day_date, 'meal':'snacks', 'meal_ind':3}) for x in diary]
    [x.update(x['nutrition_information']) for x in diary]
    [x.pop('nutrition_information', None) for x in diary]

    day_dict.pop('date', None)
    res = [day_dict[key] for key in day_dict.keys()]
    res = [item for sublist in res for item in sublist]
    return res

daily_diary_df = [add_date_meal_to_diary(d) for d in daily_diary_saved]
daily_diary_df = [item for sublist in daily_diary_df for item in sublist]
daily_diary_df = pd.DataFrame(daily_diary_df).fillna(0)

daily_diary_df.sort_values(['date', 'meal_ind'], inplace=True)
daily_diary_df.reset_index(inplace=True, drop=True)
daily_diary_df = daily_diary_df[['date', 'meal', 'name', 'calories', 'carbohydrates', 'fat', 'protein', 'sodium', 'sugar']]
daily_diary_df.to_csv(food_diary_file, index=False)

# %% [markdown]
# ## Fitbit

# %% [markdown]
# NOTES:
#
# The Fitbit API is rate limited at **150 requests / hour / user**.

# %% [markdown]
# Some additional data to possibly get in the future, e.g. each lives in its own file, multiple rows per date:
# ```
# 'distances': [
#     {'activity': 'total', 'distance': 4.27},
#     {'activity': 'tracker', 'distance': 4.27},
#     {'activity': 'loggedActivities', 'distance': 0},
#     {'activity': 'veryActive', 'distance': 1.41},
#     {'activity': 'moderatelyActive', 'distance': 0.43},
#     {'activity': 'lightlyActive', 'distance': 2.43},
#     {'activity': 'sedentaryActive', 'distance': 0}
# ]
#
# 'heartRateZones': [
#     {'caloriesOut': 1839.97352,'max': 103, 'min': 30, 'minutes': 1210, 'name': 'Out of Range'},
#     {'caloriesOut': 806.60118, 'max': 125, 'min': 103, 'minutes': 158, 'name': 'Fat Burn'},
#     {'caloriesOut': 0, 'max': 154, 'min': 125, 'minutes': 0, 'name': 'Cardio'},
#     {'caloriesOut': 0, 'max': 220, 'min': 154, 'minutes': 0, 'name': 'Peak'}
# ]
# ```

# %%
parser = configparser.ConfigParser()
parser.read(cfg_file)
consumer_key = parser.get('fitbit', 'consumer_key')
consumer_secret = parser.get('fitbit', 'consumer_secret')
access_token = parser.get('fitbit', 'access_token')
refresh_token = parser.get('fitbit', 'refresh_token')
expires_at = parser.get('fitbit', 'expires_at')

auth_client = fitbit.Fitbit(consumer_key, consumer_secret,
                            access_token=access_token,
                            refresh_token=refresh_token,
                            expires_at=float(expires_at),
                            refresh_cb=(lambda x: persist_fitbit_refresh_token(x, cfg_file)),
                            api_version=1 # use 1.2 for sleep, otherwise 1
                            )

# %% [markdown]
# ### Daily steps

# %%
start_date = datetime.datetime.strptime('2013-01-14', '%Y-%m-%d').date()
end_date = datetime.datetime.strptime('2015-12-31', '%Y-%m-%d').date()
# num_days = (end_date - start_date).days+1
steps1 = auth_client.time_series('activities/steps', base_date=start_date, end_date=end_date)
steps1_df = pd.DataFrame(steps1['activities-steps']).rename({'dateTime':'date', 'value':'steps'}, axis=1)

start_date = datetime.datetime.strptime('2016-01-01', '%Y-%m-%d').date()
end_date = datetime.datetime.strptime('2018-06-30', '%Y-%m-%d').date()
# num_days = (end_date - start_date).days+1
steps2 = auth_client.time_series('activities/steps', base_date=start_date, end_date=end_date)
steps2_df = pd.DataFrame(steps2['activities-steps']).rename({'dateTime':'date', 'value':'steps'}, axis=1)

start_date = datetime.datetime.strptime('2018-07-01', '%Y-%m-%d').date()
end_date = datetime.datetime.strptime('2021-01-24', '%Y-%m-%d').date()
# num_days = (end_date - start_date).days+1
steps3 = auth_client.time_series('activities/steps', base_date=start_date, end_date=end_date)
steps3_df = pd.DataFrame(steps3['activities-steps']).rename({'dateTime':'date', 'value':'steps'}, axis=1)

# %%
steps_df = pd.concat([steps1_df, steps2_df, steps3_df])
steps_df.date = pd.to_datetime(steps_df.date)
steps_df.steps = steps_df.steps.astype('int')
dates_df = pd.DataFrame({'date':pd.date_range('2013-01-01', '2021-01-24', freq='d')})
steps_df = pd.merge(dates_df, steps_df, on='date', how='left')
steps_df.loc[steps_df.steps<100, 'steps'] = np.nan

steps_df.to_csv(steps_daily_file, index=False)

# %% [markdown]
# ### Daily activities raw data

# %%
start_date = '2020-11-04'
end_date = '2021-01-24'
date_start = datetime.datetime.strptime(start_date, '%Y-%m-%d')
date_end = datetime.datetime.strptime(end_date, '%Y-%m-%d')
date_query = date_start
date_diff = date_end - date_query
days = date_diff.days+1
days
# Out:
# 82

# %%
my_activities = []
dates = []

# API calls
for i in range(days):
    print(date_query.strftime('%Y-%m-%d'))    
    activity = auth_client.activities(date=date_query)
    dates.append(date_query.strftime('%Y-%m-%d'))
    my_activities.append(activity)
    date_query = date_query + datetime.timedelta(days=1)
# Out:
# 2020-11-04
# 2020-11-05
# 2020-11-06
# 2020-11-07
# 2020-11-08
# 2020-11-09
# 2020-11-10
# 2020-11-11
# 2020-11-12
# 2020-11-13
# 2020-11-14
# 2020-11-15
# 2020-11-16
# 2020-11-17
# 2020-11-18
# 2020-11-19
# 2020-11-20
# 2020-11-21
# 2020-11-22
# 2020-11-23
# 2020-11-24
# 2020-11-25
# 2020-11-26
# 2020-11-27
# 2020-11-28
# 2020-11-29
# 2020-11-30
# 2020-12-01
# 2020-12-02
# 2020-12-03
# 2020-12-04
# 2020-12-05
# 2020-12-06
# 2020-12-07
# 2020-12-08
# 2020-12-09
# 2020-12-10
# 2020-12-11
# 2020-12-12
# 2020-12-13
# 2020-12-14
# 2020-12-15
# 2020-12-16
# 2020-12-17
# 2020-12-18
# 2020-12-19
# 2020-12-20
# 2020-12-21
# 2020-12-22
# 2020-12-23
# 2020-12-24
# 2020-12-25
# 2020-12-26
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
# 2021-01-01
# 2021-01-02
# 2021-01-03
# 2021-01-04
# 2021-01-05
# 2021-01-06
# 2021-01-07
# 2021-01-08
# 2021-01-09
# 2021-01-10
# 2021-01-11
# 2021-01-12
# 2021-01-13
# 2021-01-14
# 2021-01-15
# 2021-01-16
# 2021-01-17
# 2021-01-18
# 2021-01-19
# 2021-01-20
# 2021-01-21
# 2021-01-22
# 2021-01-23
# 2021-01-24

# %%
# add date field
[my_activities[i].update({'date':dates[i]}) for i in range(len(dates))]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# save raw json to file
with open(steps_activity_dir+'fitbit_activities_20201104_to_20210124.json', 'w') as outfile:
    json.dump(my_activities, outfile, indent=3)

# %% [markdown]
# ### Individual activity data

# %%
# read saved raw data
with open(steps_activity_dir+'fitbit_activities_20150117_to_20201103.json') as data_file:
    fitbit_activities = json.load(data_file)
    
with open(steps_activity_dir+'fitbit_activities_20201104_to_20210124.json') as data_file:
    temp = json.load(data_file)
    
fitbit_activities = fitbit_activities + temp

# %%
def get_activity_types(entry):
    act = entry['activities']
    if len(act)==0:
        return []
    return [x['name'] for x in act]

# %%
foo = [get_activity_types(x) for x in fitbit_activities]
foo = [j for i in foo for j in i]
foo = pd.DataFrame({'name':foo})

# %%
foo.name.value_counts()
# Out:
# Walk               2678
# Run                 435
# Sport               102
# Outdoor Bike          6
# Aerobic Workout       1
# Elliptical            1
# Name: name, dtype: int64

# %%
def get_single_activity(activity_data):
    act_type = activity_data['name']
    if act_type in ['Outdoor Bike', 'Aerobic Workout', 'Elliptical']:
        return {}
    date = activity_data['startDate']
    tod = activity_data['startTime']
    timestamp = date + ' ' + tod
    duration_mins = round(activity_data['duration']/1000/60, 2)
    calories = activity_data['calories']
    steps = activity_data['steps']
    return {
        'date': date,
        'timestamp': timestamp,
        'duration_mins':duration_mins,
        'activity_type': act_type,
        'calories':calories,
        'steps':steps
    }
    
def get_activity_for_day(day_data):
    acts = day_data['activities']
    if acts==[]:
        return acts
    res = [get_single_activity(act) for act in acts]
    return res

# %%
act_df = [get_activity_for_day(x) for x in fitbit_activities]
act_df = [item for sublist in act_df for item in sublist]
act_df = pd.DataFrame(act_df)
act_df = act_df[~act_df.date.isna()].reset_index(drop=True)

# %%
act_df.to_csv(steps_activity_dir+'activities.csv', index=False)

# %% [markdown]
# ### Daily summary of activity data

# %%
def get_activity_steps(acts, date, steps):
    steps_run = 0
    steps_walk = 0
    steps_sport = 0
    calories_run = 0
    calories_walk = 0
    calories_sport = 0
    acts_filtered = []
    for act in acts:
        if act['name'] in ['Run', 'Walk', 'Sport']:
            acts_filtered.append(act)
    if len(acts_filtered)>0:
        act_steps = pd.DataFrame([get_single_activity(act) for act in acts])
        act_steps = act_steps.groupby('activity_type').sum().reset_index()
        steps_run = act_steps[act_steps['activity_type']=='Run'].steps.sum()
        steps_walk = act_steps[act_steps['activity_type']=='Walk'].steps.sum()
        steps_sport = act_steps[act_steps['activity_type']=='Sport'].steps.sum()
        calories_run = act_steps[act_steps['activity_type']=='Run'].calories.sum()
        calories_walk = act_steps[act_steps['activity_type']=='Walk'].calories.sum()
        calories_sport = act_steps[act_steps['activity_type']=='Sport'].calories.sum()
    steps_other = round(steps - steps_run - steps_walk - steps_sport)
    return {
        'date':date,
        'steps':steps,
        'steps_run':steps_run,
        'steps_walk':steps_walk,
        'steps_sport':steps_sport,
        'steps_other':steps_other,
        'calories_run':calories_run,
        'calories_walk':calories_walk,
        'calories_sport':calories_sport
    }
        
def get_daily_act_summary(day_data):
    date = day_data['date']
    acts = day_data['activities']
    summary = day_data['summary']
    res = get_activity_steps(acts, date, summary['steps'])
    return res

# %%
act_steps_df = pd.DataFrame([get_daily_act_summary(x) for x in fitbit_activities])
act_steps_df.date = pd.to_datetime(act_steps_df.date)
act_steps_df = act_steps_df[act_steps_df.date>'2015-11-23'].reset_index(drop=True)
act_steps_df.to_csv(steps_activity_dir+'daily_activity_steps_cals.csv', index=False)

# %%
def get_daily_summary(day_data):
    date = day_data['date']
    summary = day_data['summary']
    return {
        'date':date,
        'steps':summary['steps'],
        'floors':summary['floors'],
        'heart_rate_resting':summary['restingHeartRate'],
        
        'calories_out':summary['caloriesOut'],
        'calories_active':summary['activityCalories'],
        'calories_bmr':summary['caloriesBMR'],
        
        'minutes_sedentary':summary['sedentaryMinutes'],
        'minutes_lightly_active':summary['lightlyActiveMinutes'],
        'minutes_fairly_active':summary['fairlyActiveMinutes'],
        'minutes_very_active':summary['veryActiveMinutes']        
    }

act_summary_df = pd.DataFrame([get_daily_summary(x) for x in fitbit_activities])
act_summary_df.to_csv(steps_activity_dir+'daily_summary.csv', index=False)

# %% [markdown]
# ### Detailed steps

# %%
start_date = '2021-01-11'
end_date = '2021-01-24'
date_start = datetime.datetime.strptime(start_date, '%Y-%m-%d')
date_end = datetime.datetime.strptime(end_date, '%Y-%m-%d')
date_query = date_start
date_diff = date_end - date_query
days = date_diff.days+1
days
# Out:
# 14

# %%
steps_detail_dump = []
startdate = datetime.datetime(2021, 1, 11)
date = startdate
for i in range(14): 
    print((i, ' - ', date.strftime('%Y-%m-%d')))
    datarequest = auth_client.intraday_time_series('activities/steps', base_date=date, detail_level='1min')
    time.sleep(0.35)
    steps_detail_dump.append(datarequest)
    date += datetime.timedelta(days=1)
# Out:
# (0, ' - ', '2021-01-11')
# (1, ' - ', '2021-01-12')
# (2, ' - ', '2021-01-13')
# (3, ' - ', '2021-01-14')
# (4, ' - ', '2021-01-15')
# (5, ' - ', '2021-01-16')
# (6, ' - ', '2021-01-17')
# (7, ' - ', '2021-01-18')
# (8, ' - ', '2021-01-19')
# (9, ' - ', '2021-01-20')
# (10, ' - ', '2021-01-21')
# (11, ' - ', '2021-01-22')
# (12, ' - ', '2021-01-23')
# (13, ' - ', '2021-01-24')

# %%
filename = steps_detail_dir + 'steps_detail_'+startdate.strftime('%Y-%m-%d')+'_to_'+steps_detail_dump[-1]['activities-steps'][0]['dateTime']+'.json'
filename
# Out:
# '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/fitbit/detailed_steps/steps_detail_2021-01-11_to_2021-01-24.json'

# %%
filename = steps_detail_dir + 'steps_detail_'+startdate.strftime('%Y-%m-%d')+'_to_'+steps_detail_dump[-1]['activities-steps'][0]['dateTime']+'.json'

with open(filename, 'w') as outfile:
    json.dump(steps_detail_dump, outfile, indent=3)

# %% [markdown]
# ### Detailed heart rate

# %%
start_date = '2021-01-11'
end_date = '2021-01-24'
date_start = datetime.datetime.strptime(start_date, '%Y-%m-%d')
date_end = datetime.datetime.strptime(end_date, '%Y-%m-%d')
date_query = date_start
date_diff = date_end - date_query
days = date_diff.days+1
days
# Out:
# 14

# %%
heart_detail_dump = []
startdate = datetime.datetime(2021, 1, 11)
date = startdate
for i in range(14): 
    print((i, ' - ', date.strftime('%Y-%m-%d')))
    datarequest=auth_client.intraday_time_series('activities/heart', base_date=date, detail_level='1sec')
    time.sleep(0.35)
    heart_detail_dump.append(datarequest)
    date += datetime.timedelta(days=1)
# Out:
# (0, ' - ', '2021-01-11')
# (1, ' - ', '2021-01-12')
# (2, ' - ', '2021-01-13')
# (3, ' - ', '2021-01-14')
# (4, ' - ', '2021-01-15')
# (5, ' - ', '2021-01-16')
# (6, ' - ', '2021-01-17')
# (7, ' - ', '2021-01-18')
# (8, ' - ', '2021-01-19')
# (9, ' - ', '2021-01-20')
# (10, ' - ', '2021-01-21')
# (11, ' - ', '2021-01-22')
# (12, ' - ', '2021-01-23')
# (13, ' - ', '2021-01-24')

# %%
filename = hr_detail_dir + 'heart_detail_'+startdate.strftime('%Y-%m-%d')+'_to_'+heart_detail_dump[-1]['activities-heart'][0]['dateTime']+'.json'
filename
# Out:
# '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/fitbit/detailed_heart_rate/heart_detail_2021-01-11_to_2021-01-24.json'

# %%
filename = hr_detail_dir + 'heart_detail_'+startdate.strftime('%Y-%m-%d')+'_to_'+heart_detail_dump[-1]['activities-heart'][0]['dateTime']+'.json'

with open(filename, 'w') as outfile:
    json.dump(heart_detail_dump, outfile)

# %% [markdown]
# ### Detailed sleep

# %%
start_date = '2021-01-11'
end_date = '2021-01-24'
date_start = datetime.datetime.strptime(start_date, '%Y-%m-%d')
date_end = datetime.datetime.strptime(end_date, '%Y-%m-%d')
date_query = date_start
date_diff = date_end - date_query
days = date_diff.days+1
days
# Out:
# 14

# %%
sleep_detail_dump = []
startdate = datetime.datetime(2021, 1, 11)
date = startdate
for i in range(14): 
    print((i, ' - ', date.strftime('%Y-%m-%d')))
    datarequest = auth_client.get_sleep(date)
    time.sleep(0.5)
    sleep_detail_dump.append(datarequest)
    date += datetime.timedelta(days=1)
# Out:
# (0, ' - ', '2021-01-11')
# (1, ' - ', '2021-01-12')
# (2, ' - ', '2021-01-13')
# (3, ' - ', '2021-01-14')
# (4, ' - ', '2021-01-15')
# (5, ' - ', '2021-01-16')
# (6, ' - ', '2021-01-17')
# (7, ' - ', '2021-01-18')
# (8, ' - ', '2021-01-19')
# (9, ' - ', '2021-01-20')
# (10, ' - ', '2021-01-21')
# (11, ' - ', '2021-01-22')
# (12, ' - ', '2021-01-23')
# (13, ' - ', '2021-01-24')

# %%
filename = sleep_detail_dir + 'sleep_detail_'+startdate.strftime('%Y-%m-%d')+'_to_'+sleep_detail_dump[-1]['sleep'][-1]['dateOfSleep']+'.json'
filename
# Out:
# '/Users/jamieinfinity/Dropbox/Projects/WeightForecaster/_data_dump/fitbit/detailed_sleep/sleep_detail_2021-01-11_to_2021-01-24.json'

# %%
filename = sleep_detail_dir + 'sleep_detail_'+startdate.strftime('%Y-%m-%d')+'_to_'+sleep_detail_dump[-1]['sleep'][-1]['dateOfSleep']+'.json'

with open(filename, 'w') as outfile:
    json.dump(sleep_detail_dump, outfile, indent=3)
